# %%
import pandas as pd
import re
import requests
import sqlite3

# %%
df = pd.read_hdf('pgaus.hdf', 'pgaus')

# %%
df
# Out:
#      DateAdded                                   Title and Author  \
# 0     Mar 2017                     The Solitary Farm, Fergus Hume
# 1     Mar 2017                       The Green Mummy, Fergus Hume
# 2     Mar 2017                      The Opal Serpent, Fergus Hume
# 3     Mar 2017                    The Mandarin's Fan, Fergus Hume
# 4     Mar 2017                        The Red Window, Fergus Hume
# 5     Mar 2017                   The Dwarf's Chamber, Fergus Hume
# 6     Mar 2017                  A Coin of Edward VII, Fergus Hume
# 7     Mar 2017                       The Pagan's Cup, Fergus Hume
# 8     Mar 2017             They See in Darkness, Ethel Lina White
# 9     Mar 2017          The Man Who Loved Lions, Ethel Lina White
# 10    Mar 2017       The Elephant Never Forgets, Ethel Lina White
# 11    Mar 2017                Put Out the Light, Ethel Lina White
# 12    Mar 2017           The First Time He Died, Ethel Lina White
# ...
