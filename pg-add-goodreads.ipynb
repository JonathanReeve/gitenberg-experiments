# %%
import pandas as pd
from bs4 import BeautifulSoup
from lxml import etree
from secrets import goodreadsKey
import requests
import time
import editdistance
import re

# %%
# Load data so far
df = pd.read_hdf('pg-text-5-goodreads.hdf', 'pg')

# %%
class goodReads:  
    def __init__(self, title, author=None):
        self.title = title
        self.author = author
        self.response = self.queryAPI(title, author)
        self.bestWork = self.parseResponse(self.response)
        if self.bestWork is not None: 
            self.found = True
            self.pubDate = self.bestWork.original_publication_year.text + \
                '-' + self.bestWork.original_publication_month.text + '-' + \
                self.bestWork.original_publication_day.text
            self.rating = self.bestWork.average_rating.text
            self.id = self.bestWork.id.text
            self.numReviews = self.bestWork.text_reviews_count.text
            self.authorID = self.bestWork.author.id.text
            self.imageURL = self.bestWork.image_url.text
            self.smallImageURL = self.bestWork.small_image_url.text
            self.show()
        else: 
            self.found = False
        
    def show(self): 
        print('pubDate: ', self.pubDate)
        print('rating: ', self.rating)
        print('id: ', self.id)
        print('numReviews: ', self.numReviews)
        
    def queryAPI(self, title, author): 
        url = 'https://www.goodreads.com/search.xml'
        params = [('key', goodreadsKey), ('q', title)]
        response = requests.get(url, params)
        self.lastRequest = time.time()
        return response
        
    def parseResponse(self, response): 
        if response.status_code != 200: 
            print('Got response other than 200!')
        else: 
            self.text = response.text
            self.soup = BeautifulSoup(self.text, "lxml")
            self.works = self.soup.find_all('work')
            return self.getBestWork(self.works)
    
    def getBestWork(self, works, maxTries=3):
        for i in range(min(len(works), maxTries)): 
            authorParsed = self.parseAuthor(works[i])
            if authorParsed is not None: 
                if self.similarAuthors(self.author, authorParsed): 
                    return works[i]
        print("Couldn't find an appropriate work in the list.")
        return None
            
    def parseAuthor(self, work): 
        author = work.find('author').find('name').text
        return author
        
    def similarAuthors(self, origAuthor, parsedAuthor, threshold=3): 
#         print("origAuthor: ", origAuthor)
#         print("parsedAuthor: ", parsedAuthor)
        if (type(origAuthor) == str) and (type(parsedAuthor) == str): 
            origAuthor = origAuthor.strip().lower()
            origAuthor = re.sub('\(.*?\)', '', origAuthor)
            parsedAuthor = parsedAuthor.strip().lower()
            if ',' in origAuthor: 
                # Try to change Jefferson, Thomas to Thomas Jefferson
                nameParts = origAuthor.split(',')
                origAuthor = nameParts[1] + ' ' + nameParts[0]
                # if the last name is somewhere in the name, that's good enough
                if nameParts[0] in parsedAuthor: 
                    return True
            if editdistance.eval(origAuthor, parsedAuthor) < threshold: 
                return True
            else: 
                print("Couldn't match origAuthor: %s \n with parsedAuthor: %s" % (origAuthor, parsedAuthor))
                return False
        else: 
            print("One of these authors is None, assuming it's OK.")
            return True

# %%
start, end = 53043, 100000
for i, row in df.iterrows(): 
    if i > start and i < end: 
        print('Looking up #%s: %s' % (i, row.title))
        print('By: ', row.author)
        gr = goodReads(row.title, row.author)
        if gr.found: 
            df.set_value(i, 'gr_rating', gr.rating)
            df.set_value(i, 'gr_numReviews', gr.numReviews)
            df.set_value(i, 'gr_pubDate', gr.pubDate)
            df.set_value(i, 'gr_id', gr.id)
            df.set_value(i, 'gr_info', str(gr.bestWork))
            df.set_value(i, 'gr_author_id', gr.authorID)
            df.set_value(i, 'gr_image_url', gr.imageURL)
            df.set_value(i, 'gr_small_image_url', gr.smallImageURL)
        time.sleep(1)
# Out:
# Looking up #53044: Three Days on the Ohio River
# By:  Alcott, William A. (William Andrus)
# Couldn't find an appropriate work in the list.
# Looking up #53045: The Irish Penny Journal, Vol. 1, No. 18, October 31, 1840
# By:  Various
# pubDate:  --
# rating:  0.0
# id:  56354618
# numReviews:  0
# Looking up #53046: Conscience and Sin: Daily Meditations for Lent
# By:  Baring-Gould, S. (Sabine)
# Couldn't find an appropriate work in the list.
# Looking up #53047: What Jesus Taught
# By:  Widtsoe, Osborne J. P.
# Couldn't find an appropriate work in the list.
# Looking up #53048: The American Missionary — Volume 33, No. 8, August, 1879
# By:  Various
# pubDate:  2006-3-16
# rating:  0.0
# id:  13035293
# numReviews:  0
# Looking up #53049: Charlie Codman's Cruise: A Story for Boys
# By:  Alger, Horatio, Jr.
# pubDate:  --
# rating:  0.0
# id:  56255776
# numReviews:  0
# Looking up #53050: Short Reasons for Communion with the Church of England: or the Churchman's answer to the question, "Why are you a Member of the Established Church?"
# By:  Biddulph, T. T.
# Couldn't find an appropriate work in the list.
# Looking up #53051: The German Army in Belgium, the White Book of May 1915
# By:  Bennett, E. N.
# Couldn't find an appropriate work in the list.
# Looking up #53052: The Irish Penny Journal, Vol. 1 No. 19, November 7, 1840
# By:  Various
# Couldn't find an appropriate work in the list.
# Looking up #53053: Scrap Book of Mormon Literature, Volume 2 (of 2): Religious Tracts
# By:  Various
# Couldn't find an appropriate work in the list.
# Looking up #53054: Copyright Renewals: Artwork 1960-1964: Catalog of Copyright Entries
# By:  Congress, U. S. Copyright Office Library of
# Couldn't find an appropriate work in the list.
# Looking up #53055: Marks' first lessons in geometry: in two parts. Objectively presented, and designed for the; use of primary classes in grammar schools, academies, etc.
# By:  Marks, Bernhard
# pubDate:  2015-9-27
# rating:  0.0
# id:  46978045
# numReviews:  0
# Looking up #53056: Biografia di Giuseppe Garibaldi
# By:  Cuneo, Giovanni Battista
# pubDate:  --
# rating:  0.0
# id:  56261862
# numReviews:  0
# Looking up #53057: College Men Without Money
# By:  Riddle, Carl
# Couldn't find an appropriate work in the list.
# Looking up #53058: John Holdsworth: Chief Mate
# By:  Russell, William Clark
# pubDate:  1875--
# rating:  4.00
# id:  26647366
# numReviews:  0
# Looking up #53059: Urith: A Tale of Dartmoor
# By:  Baring-Gould, S. (Sabine)
# Couldn't find an appropriate work in the list.
# Looking up #53060: Meine Tante Anna
# By:  Villinger, Hermine
# pubDate:  --
# rating:  0.0
# id:  55981303
# numReviews:  0
# Looking up #53061: Mirdja: Romaani
# By:  Onerva, L.
# Couldn't find an appropriate work in the list.
# Looking up #53062: Tarzanin paluu: Seikkailukirja Afrikan aarniometsistä
# By:  Burroughs, Edgar Rice
# pubDate:  --
# rating:  0.0
# id:  55735312
# numReviews:  0
# Looking up #53063: Les poilus canadiens: Le roman du vingt-deuxième bataillon canadien-français
# By:  Holland, J. A.
# Couldn't find an appropriate work in the list.
# Looking up #53064: Ancient Apostles
# By:  McKay, David O.
# pubDate:  2009-8-14
# rating:  5.00
# id:  14676715
# numReviews:  1
# Looking up #53065: Kitty Alone (vol 1 of 3): A Story of Three Fires
# By:  Baring-Gould, S. (Sabine)
# Couldn't find an appropriate work in the list.
# Looking up #53066: Collection complète des oeuvres de l'Abbé de Mably, Volume 4
# By:  Mably, Abbé de
# pubDate:  --
# rating:  0.0
# id:  56257468
# numReviews:  0
# Looking up #53067: Mons, Anzac and Kut
# By:  Herbert, Aubrey
# pubDate:  2010-1-2
# rating:  0.0
# id:  26198004
# numReviews:  0
# Looking up #53068: Ampleforth College; A Sketch-Book
# By:  Pike, Joseph
# Couldn't find an appropriate work in the list.
# Looking up #53069: Bruges; A Sketch-Book
# By:  Pike, Joseph
# pubDate:  --
# rating:  0.0
# id:  49535767
# numReviews:  0
# Looking up #53070: Cardiff; A Sketch-Book
# By:  Andrews, Douglas S.
# Couldn't find an appropriate work in the list.
# Looking up #53071: Durham; A Sketch-Book
# By:  Bertram, Robert J. S.
# Couldn't find an appropriate work in the list.
# Looking up #53072: Isle of Wight; A Sketch-Book
# By:  Woollard, Dorothy E.G.
# Couldn't find an appropriate work in the list.
# Looking up #53073: The English Lakes; A Sketch-Book
# By:  Home, Gordon
# Couldn't find an appropriate work in the list.
# Looking up #53074: Liverpool; A Sketch-Book
# By:  Brown, Sam J. M.
# Couldn't find an appropriate work in the list.
# Looking up #53075: London; A Sketch-Book
# By:  Hornby, Lester G. (Lester George)
# Couldn't find an appropriate work in the list.
# Looking up #53076: Newcastle-Upon-Tyne; A Sketch-Book
# By:  Bertram, Robert J. S.
# pubDate:  --
# rating:  0.0
# id:  56911792
# numReviews:  0
# Looking up #53077: Norwich; A Sketch-Book
# By:  Cole, E.V.
# Couldn't find an appropriate work in the list.
# Looking up #53078: Paris; A Sketch-Book
# By:  Béjot, Eugène
# Couldn't find an appropriate work in the list.
# Looking up #53079: Stratford-on-Avon; A Sketch-Book
# By:  Home, Gordon
# pubDate:  2009-1-1
# rating:  5.00
# id:  55662640
# numReviews:  1
# Looking up #53080: Surrey; A Sketch-Book
# By:  Austin, R.S.
# pubDate:  --
# rating:  0.0
# id:  55836034
# numReviews:  0
# Looking up #53081: The Thames
# By:  Sharpley, R.
# Couldn't find an appropriate work in the list.
# Looking up #53082: Winchester; A Sketch-Book
# By:  Home, Gordon
# pubDate:  --
# rating:  0.0
# id:  48940474
# numReviews:  0
# Looking up #53083: York; A Sketch-Book
# By:  Home, Gordon
# Couldn't find an appropriate work in the list.
# Looking up #53084: Symmes's Theory of Concentric Spheres: Demonstrating that the Earth is hollow, habitable within,; and widely open about the poles
# By:  Anonymous
# pubDate:  --
# rating:  0.0
# id:  50546825
# numReviews:  0
# Looking up #53085: How Women May Earn a Living
# By:  Grogan, Mercy
# Couldn't find an appropriate work in the list.
# Looking up #53086: Life of a Pioneer: Being the Autobiography of James S. Brown
# By:  Brown, James S.
# pubDate:  --
# rating:  0.0
# id:  56260687
# numReviews:  0
# Looking up #53087: The Æsculapian Labyrinth Explored: Medical Mystery Illustrated
# By:  Glyster, Gregory
# pubDate:  --
# rating:  0.0
# id:  55695631
# numReviews:  0
# Looking up #53088: Miriam: A Tale of Pole Hill and the Greenfield Hills
# By:  Sykes, Daniel Frederick Edward
# Couldn't find an appropriate work in the list.
# Looking up #53089: Europe in the Middle Ages
# By:  Plunket, Ierne Lifford
# Couldn't find an appropriate work in the list.
# Looking up #53090: The Women of Mormondom
# By:  Tullidge, Edward W.
# pubDate:  1957--
# rating:  4.00
# id:  6545581
# numReviews:  4
# Looking up #53091: Bath and Wells; A Sketch-Book
# By:  Andrews, D. S.
# Couldn't find an appropriate work in the list.
# Looking up #53092: Reminiscences of Joseph the Prophet: And the Coming Forth of the Book of Mormon
# By:  Stevenson, Edward Luther
# Couldn't find an appropriate work in the list.
# Looking up #53093: Q-Ships and Their Story
# By:  Chatterton, E. Keble (Edward Keble)
# pubDate:  1972-11-2
# rating:  3.47
# id:  3794697
# numReviews:  1
# Looking up #53094: L'ancien régime et la révolution
# By:  Tocqueville, Alexis de
# pubDate:  --
# rating:  0.0
# id:  56350640
# numReviews:  0
# Looking up #53095: The Art of Architectural Modelling in Paper
# By:  Richardson, T. A.
# pubDate:  2015-8-9
# rating:  0.0
# id:  46679625
# numReviews:  0
# Looking up #53096: Vertraute Briefe an eine Freundin
# By:  Garve, Christian
# pubDate:  --
# rating:  0.0
# id:  56262050
# numReviews:  0
# Looking up #53097: Sadan prosentin patriootti
# By:  Sinclair, Upton
# Couldn't find an appropriate work in the list.
# Looking up #53098: Väärällä uralla
# By:  Kianto, Ilmari
# pubDate:  1896--
# rating:  0.0
# id:  50318218
# numReviews:  0
# Looking up #53099: Bristol; A Sketch-Book
# By:  Woollard, Dorothy E.G.
# pubDate:  2015-2-19
# rating:  0.0
# id:  46676433
# numReviews:  0
# Looking up #53100: Abridgement of the Debates of Congress, from 1789 to 1856, Vol. 3 (of 16)
# By:  Various
# Couldn't find an appropriate work in the list.
# Looking up #53101: Queens of the Renaissance
# By:  Ryley, M. Beresford
# pubDate:  1907--
# rating:  3.00
# id:  6707564
# numReviews:  1
# Looking up #53102: Autobiography of Sir John Rennie, F.R.S., Past President of the Institute of Civil Engineers: Comprising the history of his professional life, together; with reminiscences dating from the commencement of the; century to the present time.
# By:  Rennie, John
# pubDate:  2015-8-8
# rating:  0.0
# id:  46603766
# numReviews:  0
# Looking up #53103: The Slav Nations
# By:  Tucić, Srgjan Pl.
# Couldn't find an appropriate work in the list.
# Looking up #53104: Printing in Relation to Graphic Art
# By:  French, George
# pubDate:  2015-8-20
# rating:  0.0
# id:  46767682
# numReviews:  0
# Looking up #53105: Jed, the Poorhouse Boy
# By:  Alger, Horatio, Jr.
# pubDate:  --
# rating:  0.0
# id:  56173586
# numReviews:  0
# Looking up #53106: In Beaver Cove and Elsewhere
# By:  Crim, Matt
# pubDate:  2007-10-1
# rating:  0.0
# id:  19957096
# numReviews:  0
# Looking up #53107: Istruzioni popolari per la buona tenuta dei bachi da seta
# By:  Poggi, Tito
# Couldn't find an appropriate work in the list.
# Looking up #53108: Des Vaters Sünde, der Mutter Fluch
# By:  Clauren, Heinrich
# Couldn't find an appropriate work in the list.
# Looking up #53109: Glasgow; A Sketch-Book
# By:  Nisbet, John
# Couldn't find an appropriate work in the list.
# Looking up #53110: Harrow; A Sketch-Book
# By:  Keesey, Walter M.
# pubDate:  --
# rating:  0.0
# id:  55855713
# numReviews:  0
# Looking up #53111: Runeberg Suomen kansan runoilijana
# By:  Vasenius, Valfrid
# pubDate:  --
# rating:  0.0
# id:  10394143
# numReviews:  0
# Looking up #53112: Lehrbuch der Physik zum Schulgebrauche.
# By:  Winter, Wilhelm
# Couldn't find an appropriate work in the list.
# Looking up #53113: Gettysburg: Stories of the Red Harvest and the Aftermath
# By:  Singmaster, Elsie
# pubDate:  1913--
# rating:  3.00
# id:  3710498
# numReviews:  0
# Looking up #53114: Suomalaisia
# By:  Wainio, Niilo E.
# Couldn't find an appropriate work in the list.
# Looking up #53115: The Silicon Jungle
# By:  Rothman, David H.
# Couldn't find an appropriate work in the list.
# Looking up #53116: The Works of John Dryden, Now First Collected in Eighteen Volumes; Vol. 12 (of 18)
# By:  Dryden, John
# pubDate:  --
# rating:  0.0
# id:  50214033
# numReviews:  0
# Looking up #53117: Lakiasia: Näytelmä kolmessa näytöksessä
# By:  Karikko, Kaarle
# Couldn't find an appropriate work in the list.
# Looking up #53118: Kolmimasto "Tulevaisuus" eli elämää Pohjolassa
# By:  Lie, Jonas
# Couldn't find an appropriate work in the list.
# Looking up #53119: The Brighton Boys in the Submarine Treasure Ship
# By:  Driscoll, Lieutenant James R.
# Couldn't find an appropriate work in the list.
# Looking up #53120: A History of the Old English Letter Foundries: with Notes, Historical and Bibliographical, on the Rise; and Progress of English Typography.
# By:  Reed, Talbot Baines
# pubDate:  1887--
# rating:  3.00
# id:  13260884
# numReviews:  0
# Looking up #53121: A Colonial Reformer, Vol. III (of 3)
# By:  Boldrewood, Rolf
# Couldn't find an appropriate work in the list.
# Looking up #53122: A Blundering Boy: A Humorous Story
# By:  Munro, Bruce Weston
# pubDate:  2015-9-27
# rating:  0.0
# id:  46995555
# numReviews:  0
# Looking up #53123: Die Harpyen von Madrit, oder die Postkutsche: Aus dem Spanischen des Verfassers der Donna Rufina
# By:  Solórzano, Alonso de Castillo
# Couldn't find an appropriate work in the list.
# Looking up #53124: The Romance of Madame Tussaud's
# By:  Tussaud, John Theodore
# pubDate:  2009-10-24
# rating:  3.00
# id:  14031275
# numReviews:  2
# Looking up #53125: What's What in America
# By:  Brewster, Eugene V.
# Couldn't find an appropriate work in the list.
# Looking up #53126: With Force and Arms: A Tale of Love and Salem Witchcraft
# By:  Garis, Howard Roger
# Couldn't find an appropriate work in the list.
# Looking up #53127: The Royal Pastime of Cock-fighting: The art of breeding, feeding, fighting, and curing cocks of the game
# By:  R. H. (Robert Howlett)
# Couldn't find an appropriate work in the list.
# Looking up #53128: Red Spider, Volume 1 (of 2)
# By:  Baring-Gould, S. (Sabine)
# Couldn't find an appropriate work in the list.
# Looking up #53129: Red Spider, Volume 2 (of 2)
# By:  Baring-Gould, S. (Sabine)
# Couldn't find an appropriate work in the list.
# Looking up #53130: Pleasant Ways in Science
# By:  Proctor, Richard A. (Richard Anthony)
# pubDate:  2015-9-27
# rating:  0.0
# id:  46977368
# numReviews:  0
# Looking up #53131: The Catholic World, Vol. 21, April, 1875, to September, 1875: A Monthly Magazine of General Literature and Science
# By:  Various
# Couldn't find an appropriate work in the list.
# Looking up #53132: Through the Telescope
# By:  Baikie, James
# Couldn't find an appropriate work in the list.
# Looking up #53133: Vanha pappila
# By:  Kianto, Ilmari
# Couldn't find an appropriate work in the list.
# Looking up #53134: A Battle of the Books, recorded by an unknown writer for the use of authors and publishers: To the first for doctrine, to the second for reproof, to; both for correction and for instruction in righteousness
# By:  Hamilton, Gail
# pubDate:  2010-4-21
# rating:  0.0
# id:  13595412
# numReviews:  0
# Looking up #53135: Collecting Old Glass: English and Irish
# By:  Yoxall, J. H.
# pubDate:  --
# rating:  0.0
# id:  49892924
# numReviews:  0
# Looking up #53136: Inari: Romaani
# By:  Onerva, L.
# Couldn't find an appropriate work in the list.
# Looking up #53137: The American Railway: Its Construction, Development, Management, and Appliances
# By:  Bogart, John
# Couldn't find an appropriate work in the list.
# Looking up #53138: Dramatized Readings: Recitations in Poetry and Prose: Preston Library No. 1
# By:  Yendes, Lucy A.
# Couldn't find an appropriate work in the list.
# Looking up #53139: Pyhä viha: Romaani
# By:  Kianto, Ilmari
# Couldn't find an appropriate work in the list.
# Looking up #53140: Paris en América
# By:  Lefebvre, Renato
# Couldn't find an appropriate work in the list.
# Looking up #53141: Histoires souveraines
# By:  L'Isle-Adam, Auguste de Villiers de
# Couldn't find an appropriate work in the list.
# Looking up #53142: The Irish Penny Journal, Vol. 1 No. 20, November 14, 1840
# By:  Various
# Couldn't find an appropriate work in the list.
# Looking up #53143: Nelson The Newsboy: Or, Afloat in New York
# By:  Stratemeyer, Edward
# Couldn't find an appropriate work in the list.
# Looking up #53144: Köyhäin aarteet
# By:  Maeterlinck, Maurice
# pubDate:  1896--
# rating:  3.91
# id:  1207891
# numReviews:  20
# Looking up #53145: Schilderungen des Treibens im Leben und Handel in den Vereinigten Staaten und Havana.: Gezeichnet auf Reisen in den Jahren 1838 und 1839
# By:  Ries, Julius
# pubDate:  2013-4-21
# rating:  0.0
# id:  28152834
# numReviews:  0
# Looking up #53146: A Complete History of Music: for Schools, Clubs, and Private Readings
# By:  Baltzell, W. J. (Winton James)
# Couldn't find an appropriate work in the list.
# Looking up #53147: Prétextes: Réflexions sur quelques points de littérature et de morale
# By:  Gide, André
# pubDate:  --
# rating:  0.0
# id:  56327962
# numReviews:  0
# Looking up #53148: A Biography of the Signers of the Declaration of Independence, and of Washington and Patrick Henry: With an appendix, containing the Constitution of the United; States and other documents
# By:  Judson, L. Carroll (Levi Carroll)
# pubDate:  2010-8-1
# rating:  3.00
# id:  13910785
# numReviews:  0
# Looking up #53149: Nirvana: Lemmentarina
# By:  Kianto, Ilmari
# Couldn't find an appropriate work in the list.
# Looking up #53150: The Irish Penny Journal, Vol. 1 No. 21, November 21, 1840
# By:  Various
# Couldn't find an appropriate work in the list.
# Looking up #53151: Lois psychologiques de l'évolution des peuples
# By:  Le Bon, Gustave
# pubDate:  1898--
# rating:  3.46
# id:  7382625
# numReviews:  47
# Looking up #53152: Kertomuksia Intiasta
# By:  Kipling, Rudyard
# pubDate:  1955--
# rating:  0.0
# id:  53934219
# numReviews:  0
# Looking up #53153: Mehalah: A Story of the Salt Marshes
# By:  Baring-Gould, S. (Sabine)
# Couldn't find an appropriate work in the list.
# Looking up #53154: Motor Tours in the West Country
# By:  Stawell, Rodolph, Mrs.
# Couldn't find an appropriate work in the list.
# Looking up #53155: The Religious Thought of the Greeks
# By:  Moore, Clifford Herschel
# pubDate:  2003-4-1
# rating:  3.00
# id:  18172981
# numReviews:  0
# Looking up #53156: Gleaning of a Mystic: A Series of Essays on Practical Mysticism
# By:  Heindel, Max
# pubDate:  --
# rating:  0.0
# id:  51855317
# numReviews:  0
# Looking up #53157: Valittuja kertomuksia
# By:  Kipling, Rudyard
# Couldn't find an appropriate work in the list.
# Looking up #53158: New England Joke Lore: The Tonic of Yankee Humor
# By:  Crandall, Arthur George
# pubDate:  --
# rating:  0.0
# id:  49430667
# numReviews:  0
# Looking up #53159: Piccole anime
# By:  None
# One of these authors is None, assuming it's OK.
# pubDate:  2011-9-10
# rating:  4.00
# id:  17947664
# numReviews:  1
# Looking up #53160: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53161: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53162: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53163: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53164: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53165: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53166: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53167: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53168: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53169: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53170: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53171: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53172: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53173: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53174: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53175: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53176: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53177: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53178: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53179: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53180: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53181: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53182: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53183: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53184: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53185: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53186: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53187: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53188: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53189: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53190: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53191: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53192: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53193: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53194: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53195: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53196: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061
# Looking up #53197: nan
# By:  nan
# One of these authors is None, assuming it's OK.
# pubDate:  2012-1-10
# rating:  4.27
# id:  16827462
# numReviews:  140061

# %%
df.to_hdf('pg-text-6-goodreads.hdf', 'pg')

# %%
len(df)
