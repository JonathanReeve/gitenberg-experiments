# %%
import pandas as pd
import glob
import os
import gutenberg
from gutenberg.cleanup import strip_headers
import sqlite3 as sql
import requests
import urllib
import json
from collections import Counter
from ast import literal_eval

# %%
df = pd.read_hdf('pg-text-3-filenames.hdf')

# %%
class DBPedia(): 
    """ Looks up metadata about a book from DBPedia, 
    using fuzzy matching on the title and author. """
    def __init__(self, title=None, author=None, resource=None):
        if resource==None and (title==None or author==None): 
            print('Must specify either the resource URI stub, or title and author.')
            raise
        if resource is not None: 
            resource = urllib.parse.unquote(resource)
            self.resourceURI = "http://dbpedia.org/resource/" + resource
        else: 
            response = self.getMeta(title, author)
            parsed = self.parseMeta(response)
            self.resourceURI = self.getResourceURI(parsed)
    
        if self.resourceURI is not None: 
            resourceResponse = self.queryDBP(self.resourceURI)
            resourceParsed = self.parseMeta(resourceResponse)
            self.info = self.getInfo(resourceParsed)
            if self.info is not None: 
                self.pubDate = self.getPubDate()
                self.subjects = self.getSubjects()
                self.literaryGenres = self.getLiteraryGenres()
            else: 
                self._abort()
        else: 
            self._abort()
        
    def _abort(self): 
        self.info = None 
        self.pubDate = None
        self.subjects = None
        self.literaryGenres = None
    
    def getMeta(self, title, author): 
        query = """select distinct ?book
                where {
                  # ?book a dbo:Book .
                  # ?book dbo:author ?author .
                  # ?book dbp:name ?name .
                  FILTER (regex(?name, "%s"))
                  FILTER (regex(?author, "%s"))
                } 
                LIMIT 100""" % (title, author)
        response = requests.get("http://dbpedia.org/sparql", 
                                params=[('query', query), 
                                        ('format', 'application/json')])
        return response

    def parseMeta(self, dbpResponse): 
        try: 
            parsed = json.loads(dbpResponse.text)
        except: 
            print("Couldn't decode JSON: ", dbpResponse.text)
            return None
        return parsed

    def getResourceURI(self, jsonMeta): 
        try: 
            bindings = jsonMeta['results']['bindings']
        except KeyError: 
            print("Couldn't find the appropriate results in the JSON: ", jsonMeta)
            return None
        try: 
            uri = bindings[0]['book']['value']
        except IndexError: 
            print("Couldn't find a resource URI. There is no 0th element in the JSON: ", jsonMeta)
            return None
        return uri
    
    def queryDBP(self, resourceURI):
        query = 'DESCRIBE <%s>' % resourceURI
        params = [('default-graph-uri', 'http://dbpedia.org'), 
                  ('query', query), ('format', 'application/json')]
        r = requests.get("http://dbpedia.org/sparql", params=params)
        return r

    def getInfo(self, jsonData):
        try: 
            data = jsonData[self.resourceURI]
            return data
        except KeyError: 
            print('Strangely, there is no entry in items for this item. Jsondata: ', jsonData)
        
    
    def getPubDate(self): 
        try: 
            releaseDate = self.info['http://dbpedia.org/ontology/releaseDate']
        except KeyError: 
            print('No releaseDate in self.info ontology. Trying property.')
            print('Available info: ', self.info.keys())
            try: 
                releaseDate = self.info['http://dbpedia.org/property/releaseDate']
            except KeyError: 
                print('No releaseDate in self.info property. Giving up.')
                return None
        try: 
            firstRelease = releaseDate[0]
        except IndexError: 
            print('There is no 0th release, apparently: ', releaseDate)
            return None
        try: 
            date = firstRelease['value']
        except KeyError: 
            print('Strangely, no actual date in releaseDate:', releaseDate)
            return None
        return date
    
    def getSubjects(self): 
        subjects = []
        try: 
            subjs = self.info['http://purl.org/dc/terms/subject']
        except KeyError: 
            print('No subject in self.info.')
            return None
        for subj in subjs: 
            subject = subj['value'].split('/')[-1]
            if subject.startswith('Category:'): 
                subject = subject[9:]
            subjects.append(subject)
        return subjects
    
    def getLiteraryGenres(self): 
        literaryGenres = []
        try: 
            genres = self.info['http://dbpedia.org/ontology/literaryGenre']
        except KeyError: 
            print('No literary genre in self.info.')
            return None
        for genre in genres: 
            literaryGenre = genre['value'].split('/')[-1]
            literaryGenres.append(literaryGenre)
        return literaryGenres

# %%
uly = DBPedia('Ulysses', 'Joyce')

# %%
uly.pubDate
# Out:
# '1922-02-02'

# %%
pp = DBPedia("Pilgrim's Progress", "Bunyan")
# Out:
# No releaseDate in self.info ontology. Trying property.
# Available info:  dict_keys(['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#comment', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/prov#wasDerivedFrom', 'http://dbpedia.org/ontology/abstract', 'http://dbpedia.org/ontology/author', 'http://xmlns.com/foaf/0.1/name', 'http://dbpedia.org/property/name', 'http://xmlns.com/foaf/0.1/depiction', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', 'http://dbpedia.org/ontology/thumbnail', 'http://purl.org/dc/terms/subject', 'http://dbpedia.org/ontology/wikiPageID', 'http://dbpedia.org/ontology/wikiPageRevisionID', 'http://dbpedia.org/ontology/wikiPageExternalLink', 'http://dbpedia.org/property/author'])
# No releaseDate in self.info property. Giving up.
# No literary genre in self.info.

# %%
df[df.subjects.notnull()].subjects.loc[2]
# Out:
# "['Government -- United States']"

# %%
twi = DBPedia(resource="The_Twilight_of_the_Gods_and_Other_Tales")
# Out:
# No releaseDate in self.info ontology. Trying property.
# Available info:  dict_keys(['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#comment', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/prov#wasDerivedFrom', 'http://dbpedia.org/ontology/abstract', 'http://dbpedia.org/ontology/author', 'http://dbpedia.org/ontology/country', 'http://dbpedia.org/ontology/language', 'http://dbpedia.org/ontology/literaryGenre', 'http://dbpedia.org/ontology/mediaType', 'http://dbpedia.org/ontology/numberOfPages', 'http://dbpedia.org/ontology/publisher', 'http://xmlns.com/foaf/0.1/name', 'http://dbpedia.org/property/name', 'http://xmlns.com/foaf/0.1/depiction', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', 'http://dbpedia.org/ontology/thumbnail', 'http://purl.org/dc/terms/subject', 'http://dbpedia.org/ontology/wikiPageID', 'http://dbpedia.org/ontology/wikiPageRevisionID', 'http://dbpedia.org/ontology/wikiPageExternalLink', 'http://dbpedia.org/property/author', 'http://dbpedia.org/property/country', 'http://dbpedia.org/property/genre', 'http://dbpedia.org/property/language', 'http://dbpedia.org/property/mediaType', 'http://dbpedia.org/property/pages', 'http://dbpedia.org/property/publisher'])
# No releaseDate in self.info property. Giving up.

# %%
def getResource(wikiPagesRaw): 
    try: 
        wikiList = literal_eval(wikiPagesRaw)
    except ValueError: 
        return None
    for item in wikiList: 
        if 'en.wikipedia.org' in item: 
            return item.split('/')[-1]
    return None

# %%
def sanitizeTitle(title): 
    # Grab the first part of the title, before any colon. 
    if ':' in title: 
        title = title.split(':')[0]
    # If there are quotation marks, remove everything after. 
    if '"' in title: 
        title = title.split('"')[0]
    # If there are parentheses, remove everything after.
    if "(" in title: 
        title = title.split('(')[0]
    return title

# %%
def lookupStuff(start=0):
    times = 0
    for i, row in df.iterrows(): 
        if i<start: 
            continue
        print('------------ Processing row %s -------------' % i)
        resource = getResource(row.wikipedia)
        times += 1
        if resource is not None: 
            print('Getting resource: ', resource)
            book = DBPedia(resource=resource)
        else: 
            print('Looking up by title and author.')
            if row.title is not None: 
                title = sanitizeTitle(row.title)
                print('Using title: ', title)
            else: 
                continue
            author = row.author
            if author is not None: 
                author = row.author.split(',')[0]
                author = sanitizeTitle(author) # sanitize in the same way as titles
                print('Using author: ', author)
                book = DBPedia(title = title, author=author)
            else: 
                book = None
        if book is not None: 
            pubdate = book.pubDate
            print('Pubdate: ', pubdate)
            if pubdate is not None: 
                df.set_value(i, 'wp_publication_date', pubdate)
            subjects = book.subjects
            print('Subjects: ', subjects)
            if subjects is not None: 
                df.set_value(i, 'wp_subjects', str(subjects))
            literaryGenres = book.literaryGenres
            print('Literary genres: ', literaryGenres)
            if literaryGenres is not None: 
                df.set_value(i, 'wp_literary_genres', str(literaryGenres))
            if book.info is not None: 
                df.set_value(i, 'wp_info', str(book.info))

# %%
lookupStuff(start=52456)
# Out:
# ------------ Processing row 52456 -------------
# Looking up by title and author.
# Using title:  Uncle Sam Abroad
# Using author:  Conner
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52457 -------------
# Looking up by title and author.
# Using title:  The Field Book
# Using author:  Maxwell
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52458 -------------
# Looking up by title and author.
# Using title:  Pohjalla
# Using author:  Gorky
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52459 -------------
# Looking up by title and author.
# Using title:  The Motor Boys Bound for Home; or, Ned, Bob and Jerry on the Wrecked Troopship
# Using author:  Young
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52460 -------------
# Looking up by title and author.
# Using title:  Harper's Outdoor Book for Boys
# Using author:  Various
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52461 -------------
# Looking up by title and author.
# Using title:  Peter Moors Fahrt nach Südwest
# Using author:  Frenssen
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52462 -------------
# Looking up by title and author.
# Using title:  St. Leon
# Using author:  Godwin
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52463 -------------
# Looking up by title and author.
# Using title:  Tacoma and Vicinity
# Using author:  Anonymous
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52464 -------------
# Looking up by title and author.
# Using title:  The American Missionary — Volume 32, No. 03, March, 1878
# Using author:  Various
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52465 -------------
# Looking up by title and author.
# Using title:  Genièvre
# Using author:  Tennyson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52466 -------------
# Looking up by title and author.
# Using title:  The Orchid
# Using author:  Grant
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52467 -------------
# Looking up by title and author.
# Using title:  The Boy Inventors' Flying Ship
# Using author:  Bonner
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52468 -------------
# Looking up by title and author.
# Using title:  Das österreichische Antlitz
# Using author:  Salten
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52469 -------------
# Looking up by title and author.
# Using title:  Mehiläispyytäjä
# Using author:  Cooper
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52470 -------------
# Looking up by title and author.
# Using title:  Sydän unhotettu
# Using author:  Putlitz
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52471 -------------
# Looking up by title and author.
# Using title:  Tuzuk-i-Jahangiri
# Using author:  Roger
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52472 -------------
# Looking up by title and author.
# Using title:  Through the Sikh War
# Using author:  Henty
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52473 -------------
# Looking up by title and author.
# Using title:  Revista de Filosofía, Año V - Nº 3 - May/1919
# Using author:  Various
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52474 -------------
# Looking up by title and author.
# Using title:  The Nootka Sound Controversy
# Using author:  Manning
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52475 -------------
# Looking up by title and author.
# Using title:  On Love
# Using author:  Stendhal
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52476 -------------
# Looking up by title and author.
# Using title:  Kaksi husaaria
# Using author:  Tolstoy
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52477 -------------
# Looking up by title and author.
# Using title:  Viviane
# Using author:  Tennyson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52478 -------------
# Looking up by title and author.
# Using title:  Early English Hero Tales
# Using author:  Marks
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52479 -------------
# Looking up by title and author.
# Using title:  Jessie Trim
# Using author:  Farjeon
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52480 -------------
# Looking up by title and author.
# Using title:  From Palmerston to Disraeli
# Using author:  Various
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52481 -------------
# Looking up by title and author.
# Using title:  Cædwalla
# Using author:  Cowper
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52482 -------------
# Looking up by title and author.
# Using title:  Azalea
# Using author:  Peattie
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52483 -------------
# Looking up by title and author.
# Using title:  Asiatic Cholera
# Using author:  Whitney
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52484 -------------
# Looking up by title and author.
# Using title:  In Partnership
# Using author:  Matthews
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52485 -------------
# Looking up by title and author.
# Using title:  The Red Cross Girls in Belgium
# Using author:  Vandercook
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52486 -------------
# Looking up by title and author.
# Using title:  Der persische Orden
# Using author:  Tschechow
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52487 -------------
# Looking up by title and author.
# Using title:  Standard Catholic Readers by Grades
# Using author:  Various
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52488 -------------
# Looking up by title and author.
# Using title:  The Fiddlers
# Using author:  Mee
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52489 -------------
# Looking up by title and author.
# Using title:  What Christmas Did for Jerusha Grumble
# Using author:  MacDonald
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52490 -------------
# Looking up by title and author.
# Using title:  The Daring Twins
# Using author:  Baum
# No releaseDate in self.info ontology. Trying property.
# Available info:  dict_keys(['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#comment', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/prov#wasDerivedFrom', 'http://dbpedia.org/ontology/abstract', 'http://dbpedia.org/ontology/author', 'http://dbpedia.org/ontology/literaryGenre', 'http://dbpedia.org/ontology/numberOfPages', 'http://dbpedia.org/ontology/publisher', 'http://xmlns.com/foaf/0.1/name', 'http://dbpedia.org/property/name', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', 'http://purl.org/dc/terms/subject', 'http://dbpedia.org/ontology/wikiPageID', 'http://dbpedia.org/ontology/wikiPageRevisionID', 'http://dbpedia.org/property/author', 'http://dbpedia.org/property/genre', 'http://dbpedia.org/property/pages', 'http://dbpedia.org/property/publisher'])
# No releaseDate in self.info property. Giving up.
# Pubdate:  None
# Subjects:  ["Children's_mystery_novels", '1911_novels', 'Fictional_twins', 'American_young_adult_novels', 'American_mystery_novels', 'Novels_about_orphans', 'Books_by_L._Frank_Baum', 'Juvenile_series']
# Literary genres:  ['Mystery_fiction']
# ------------ Processing row 52491 -------------
# Looking up by title and author.
# Using title:  The Fighting Retreat To Paris
# Using author:  Ingpen
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52492 -------------
# Looking up by title and author.
# Using title:  L'Illustration, No. 3736, 10 Oct 1914
# Using author:  Various
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52493 -------------
# Looking up by title and author.
# Using title:  The Unseen Hand
# Using author:  Kellogg
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52494 -------------
# Looking up by title and author.
# Using title:  The Duty of American Women to Their Country
# Using author:  Beecher
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52495 -------------
# Looking up by title and author.
# Using title:  The Telescope
# Using author:  Bell
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52496 -------------
# Looking up by title and author.
# Using title:  Recuerdos de Italia
# Using author:  Castelar
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52497 -------------
# Looking up by title and author.
# Using title:  Recuerdos de Italia
# Using author:  Castelar
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52498 -------------
# Looking up by title and author.
# Using title:  El misterio de un hombre pequeñito
# Using author:  Zamacois
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52499 -------------
# Looking up by title and author.
# Using title:  Sir Robert's Fortune
# Using author:  Oliphant
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52500 -------------
# Looking up by title and author.
# Using title:  Persialaisia kirjeitä
# Using author:  Montesquieu
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52501 -------------
# Looking up by title and author.
# Using title:  Among the Head-Hunters of Formosa
# Using author:  McGovern
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52502 -------------
# Looking up by title and author.
# Using title:  Richard Coeur de Lion and Blondel
# Using author:  Brontë
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52503 -------------
# Looking up by title and author.
# Using title:  The Diplomatists of Europe
# Using author:  Capefigue
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52504 -------------
# Looking up by title and author.
# Using title:  Vie de Henri Brulard, tome 1
# Using author:  Stendhal
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52505 -------------
# Looking up by title and author.
# Using title:  The Book Review Digest, Volume 13, 1917
# Using author:  Jackson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52506 -------------
# Looking up by title and author.
# Using title:  Secrets of Earth and Sea
# Using author:  Lankester
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52507 -------------
# Looking up by title and author.
# Using title:  Sissipäällikkö
# Using author:  Sienkiewicz
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52508 -------------
# Looking up by title and author.
# Using title:  The Southern Literary Messenger, Vol. I., No. 4, December, 1834
# Using author:  Various
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52509 -------------
# Looking up by title and author.
# Using title:  The Captain of the Wight
# Using author:  Cowper
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52510 -------------
# Looking up by title and author.
# Using title:  The Taleef Shereef
# Using author:  Khan
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52511 -------------
# Looking up by title and author.
# Using title:  The Judgement of Valhalla
# Using author:  Frankau
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52512 -------------
# Looking up by title and author.
# Using title:  Die Klerisei
# Using author:  Leskow
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52513 -------------
# Looking up by title and author.
# Using title:  Down South
# Using author:  Hardy
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52514 -------------
# Looking up by title and author.
# Using title:  Mary
# Using author:  Bjørnson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52515 -------------
# Looking up by title and author.
# Using title:  Orlowit
# Using author:  Gorky
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52516 -------------
# Looking up by title and author.
# Using title:  Mademoiselle de Scudéry, sa vie et sa correspondance
# Using author:  Rathery
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52517 -------------
# Looking up by title and author.
# Using title:  The Somme, Volume 2. The Second Battle of the Somme
# Using author:  Cie
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52518 -------------
# Looking up by title and author.
# Using title:  The Intermediate Sex
# Using author:  Carpenter
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52519 -------------
# Looking up by title and author.
# Using title:  The Tower Menagerie
# Using author:  Bennett
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52520 -------------
# Looking up by title and author.
# Using title:  Kabumpo in Oz
# Using author:  Thompson
# No releaseDate in self.info ontology. Trying property.
# Available info:  dict_keys(['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#comment', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/prov#wasDerivedFrom', 'http://dbpedia.org/ontology/abstract', 'http://dbpedia.org/ontology/author', 'http://dbpedia.org/ontology/illustrator', 'http://dbpedia.org/ontology/literaryGenre', 'http://dbpedia.org/ontology/mediaType', 'http://dbpedia.org/ontology/previousWork', 'http://dbpedia.org/ontology/publisher', 'http://dbpedia.org/ontology/series', 'http://dbpedia.org/ontology/subsequentWork', 'http://xmlns.com/foaf/0.1/name', 'http://dbpedia.org/property/name', 'http://xmlns.com/foaf/0.1/depiction', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', 'http://dbpedia.org/ontology/thumbnail', 'http://purl.org/dc/terms/subject', 'http://dbpedia.org/ontology/wikiPageID', 'http://dbpedia.org/ontology/wikiPageRevisionID', 'http://dbpedia.org/ontology/wikiPageExternalLink', 'http://dbpedia.org/property/precededBy', 'http://dbpedia.org/property/author', 'http://dbpedia.org/property/followedBy', 'http://dbpedia.org/property/genre', 'http://dbpedia.org/property/illustrator', 'http://dbpedia.org/property/mediaType', 'http://dbpedia.org/property/publisher', 'http://dbpedia.org/property/series'])
# No releaseDate in self.info property. Giving up.
# Pubdate:  None
# Subjects:  ['1922_novels', '1920s_fantasy_novels', 'Oz_(franchise)_books']
# Literary genres:  ["Children's_literature"]
# ------------ Processing row 52521 -------------
# Looking up by title and author.
# Using title:  Merry Tales
# Using author:  Skinner
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52522 -------------
# Looking up by title and author.
# Using title:  The Writings of Thomas Jefferson, Vol. 5
# Using author:  Jefferson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52523 -------------
# Looking up by title and author.
# Using title:  Progetto filosofico di una completa riforma del culto e dell'educazione politico-morale del popolo ebreo
# Using author:  Fernando
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52524 -------------
# Looking up by title and author.
# Using title:  Floreat Etona
# Using author:  Nevill
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52525 -------------
# Looking up by title and author.
# Using title:  Hymnological Studies
# Using author:  Lundquist
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52526 -------------
# Looking up by title and author.
# Using title:  Bee
# Using author:  France
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52527 -------------
# Looking up by title and author.
# Using title:  Eclectic Magazine of Foreign Literature, Science, and Art, Volume XLI, No. 5, May 1885
# Using author:  Various
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52528 -------------
# Looking up by title and author.
# Using title:  Eine deutsche Frau im Innern Deutsch-Ostafrikas
# Using author:  Prince
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52529 -------------
# Looking up by title and author.
# Using title:  The Mercer Boys in the Ghost Patrol
# Using author:  Wyckoff
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52530 -------------
# Looking up by title and author.
# Using title:  Studies in the Book of Revelation
# Using author:  Hunter
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52531 -------------
# Looking up by title and author.
# Using title:  The First Report of the Horncastle Teetotal Society, 1843
# Using author:  Anonymous
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52532 -------------
# Looking up by title and author.
# Using title:  Cussons' Horncastle Compendium, 1837
# Using author:  Cussons
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52533 -------------
# Looking up by title and author.
# Using title:  First Lessons in Natural Philosophy
# Using author:  Martindale
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52534 -------------
# Looking up by title and author.
# Using title:  Vie de Henri Brulard, Tome 2
# Using author:  Stendhal
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52535 -------------
# Looking up by title and author.
# Using title:  Der Weihnacht-Abend
# Using author:  Schilling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52536 -------------
# Looking up by title and author.
# Using title:  Weihnachtsabend
# Using author:  Mügge
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52537 -------------
# Looking up by title and author.
# Using title:  Mestari Olavi
# Using author:  Strindberg
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52538 -------------
# Looking up by title and author.
# Using title:  Kuolemantuomitun viimeinen päivä
# Using author:  Hugo
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52539 -------------
# Looking up by title and author.
# Using title:  Old Melbourne Memories
# Using author:  Boldrewood
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52540 -------------
# Looking up by title and author.
# Using title:  The Violin and Old Violin Makers
# Using author:  Clarke
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52541 -------------
# Looking up by title and author.
# Using title:  The Dolls on Dress Parade
# Using author:  Preston
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52542 -------------
# Looking up by title and author.
# Using title:  Renascence
# Using author:  Crane
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52543 -------------
# Looking up by title and author.
# Using title:  Elizabeth, Her Folks
# Using author:  Kay
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52544 -------------
# Looking up by title and author.
# Using title:  Pikku lordi
# Using author:  Burnett
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52545 -------------
# Looking up by title and author.
# Using title:  Sotavanhuksen joulu
# Using author:  Topelius
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52546 -------------
# Looking up by title and author.
# Using title:  Philosophical Works, v. 1
# Using author:  Hume
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52547 -------------
# Looking up by title and author.
# Using title:  Philosophical Works, v. 2
# Using author:  Hume
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52548 -------------
# Looking up by title and author.
# Using title:  A Literary History of Ireland
# Using author:  Hyde
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52549 -------------
# Looking up by title and author.
# Using title:  Within the Gates
# Using author:  Phelps
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52550 -------------
# Looking up by title and author.
# Using title:  The Prince of the House of David
# Using author:  Ingraham
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52551 -------------
# Looking up by title and author.
# Using title:  Life of Frederick Marryat
# Using author:  Hannay
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52552 -------------
# Looking up by title and author.
# Using title:  The Dyer's Guide
# Using author:  Packer
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52553 -------------
# Looking up by title and author.
# Using title:  Ranchos
# Using author:  Viana
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52554 -------------
# Looking up by title and author.
# Using title:  A General View of Positivism
# Using author:  Comte
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52555 -------------
# Looking up by title and author.
# Using title:  Orpheus and Other Poems
# Using author:  Brownlow
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52556 -------------
# Looking up by title and author.
# Using title:  La moglie di Sua Eccellenza
# Using author:  Rovetta
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52557 -------------
# Looking up by title and author.
# Using title:  Drowsy
# Using author:  Mitchell
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52558 -------------
# Looking up by title and author.
# Using title:  Report of a special committee of the City Council, on the improvement of the Fire Department
# Using author:  City Council Halifax
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52559 -------------
# Looking up by title and author.
# Using title:  The Red Fox's Son
# Using author:  Dilley
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52560 -------------
# Looking up by title and author.
# Using title:  Voyage des souverains
# Using author:  Riou
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52561 -------------
# Looking up by title and author.
# Using title:  Suburban Residences
# Using author:  Panton
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52562 -------------
# Looking up by title and author.
# Using title:  Glossarium eroticum linguae Latinae
# Using author:  Pierre-Emmanuel
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52563 -------------
# Looking up by title and author.
# Using title:  The Hope of the Katzekopfs
# Using author:  Paget
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52564 -------------
# Looking up by title and author.
# Using title:  Saint John Chrysostom, his Life and Times
# Using author:  Stephens
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52565 -------------
# Looking up by title and author.
# Using title:  The Mysterious Basket, or The Foundling
# Using author:  Anonymous
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52566 -------------
# Looking up by title and author.
# Using title:  Rescue the Perishing
# Using author:  Seibert
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52567 -------------
# Looking up by title and author.
# Using title:  The Book of Clever Beasts
# Using author:  Reed
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52568 -------------
# Looking up by title and author.
# Using title:  The History of the Maritime Wars of the Turks
# Using author:  Çelebi
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52569 -------------
# Looking up by title and author.
# Using title:  A searchlight on Germany
# Using author:  Hornaday
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52570 -------------
# Looking up by title and author.
# Using title:  Elizabeth Ann's Houseboat
# Using author:  Lawrence
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52571 -------------
# Looking up by title and author.
# Using title:  A Book of Christian Sonnets
# Using author:  Allen
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52572 -------------
# Looking up by title and author.
# Using title:  The Goddess of Reason
# Using author:  Johnston
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52573 -------------
# Looking up by title and author.
# Using title:  Poems
# Using author:  Dearmer
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52574 -------------
# Looking up by title and author.
# Using title:  The Coil of Carne
# Using author:  Oxenham
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52575 -------------
# Looking up by title and author.
# Using title:  A Short History of the Worshipful Company of Horners
# Using author:  Rosedale
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52576 -------------
# Looking up by title and author.
# Using title:  Julius, The Street Boy
# Using author:  Alger
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52577 -------------
# Looking up by title and author.
# Using title:  Footprints of Abraham Lincoln
# Using author:  Hobson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 52578 -------------
# Looking up by title and author.
# Using title:  Hygiene des Geschlechtslebens
# Using author:  Gruber
# ...
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53120 -------------
# Looking up by title and author.
# Using title:  A History of the Old English Letter Foundries
# Using author:  Reed
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53121 -------------
# Looking up by title and author.
# Using title:  A Colonial Reformer, Vol. III
# Using author:  Boldrewood
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53122 -------------
# Looking up by title and author.
# Using title:  A Blundering Boy
# Using author:  Munro
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53123 -------------
# Looking up by title and author.
# Using title:  Die Harpyen von Madrit, oder die Postkutsche
# Using author:  Solórzano
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53124 -------------
# Looking up by title and author.
# Using title:  The Romance of Madame Tussaud's
# Using author:  Tussaud
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53125 -------------
# Looking up by title and author.
# Using title:  What's What in America
# Using author:  Brewster
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53126 -------------
# Looking up by title and author.
# Using title:  With Force and Arms
# Using author:  Garis
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53127 -------------
# Looking up by title and author.
# Using title:  The Royal Pastime of Cock-fighting
# Using author:  R. H.
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53128 -------------
# Looking up by title and author.
# Using title:  Red Spider, Volume 1
# Using author:  Baring-Gould
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53129 -------------
# Looking up by title and author.
# Using title:  Red Spider, Volume 2
# Using author:  Baring-Gould
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53130 -------------
# Looking up by title and author.
# Using title:  Pleasant Ways in Science
# Using author:  Proctor
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53131 -------------
# Looking up by title and author.
# Using title:  The Catholic World, Vol. 21, April, 1875, to September, 1875
# Using author:  Various
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53132 -------------
# Looking up by title and author.
# Using title:  Through the Telescope
# Using author:  Baikie
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53133 -------------
# Looking up by title and author.
# Using title:  Vanha pappila
# Using author:  Kianto
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53134 -------------
# Looking up by title and author.
# Using title:  A Battle of the Books, recorded by an unknown writer for the use of authors and publishers
# Using author:  Hamilton
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53135 -------------
# Looking up by title and author.
# Using title:  Collecting Old Glass
# Using author:  Yoxall
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53136 -------------
# Looking up by title and author.
# Using title:  Inari
# Using author:  Onerva
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53137 -------------
# Looking up by title and author.
# Using title:  The American Railway
# Using author:  Bogart
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53138 -------------
# Looking up by title and author.
# Using title:  Dramatized Readings
# Using author:  Yendes
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53139 -------------
# Looking up by title and author.
# Using title:  Pyhä viha
# Using author:  Kianto
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53140 -------------
# Looking up by title and author.
# Using title:  Paris en América
# Using author:  Lefebvre
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53141 -------------
# Looking up by title and author.
# Using title:  Histoires souveraines
# Using author:  L'Isle-Adam
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53142 -------------
# Looking up by title and author.
# Using title:  The Irish Penny Journal, Vol. 1 No. 20, November 14, 1840
# Using author:  Various
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53143 -------------
# Looking up by title and author.
# Using title:  Nelson The Newsboy
# Using author:  Stratemeyer
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53144 -------------
# Looking up by title and author.
# Using title:  Köyhäin aarteet
# Using author:  Maeterlinck
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53145 -------------
# Looking up by title and author.
# Using title:  Schilderungen des Treibens im Leben und Handel in den Vereinigten Staaten und Havana.
# Using author:  Ries
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53146 -------------
# Looking up by title and author.
# Using title:  A Complete History of Music
# Using author:  Baltzell
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53147 -------------
# Looking up by title and author.
# Using title:  Prétextes
# Using author:  Gide
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53148 -------------
# Looking up by title and author.
# Using title:  A Biography of the Signers of the Declaration of Independence, and of Washington and Patrick Henry
# Using author:  Judson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53149 -------------
# Looking up by title and author.
# Using title:  Nirvana
# Using author:  Kianto
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53150 -------------
# Looking up by title and author.
# Using title:  The Irish Penny Journal, Vol. 1 No. 21, November 21, 1840
# Using author:  Various
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53151 -------------
# Looking up by title and author.
# Using title:  Lois psychologiques de l'évolution des peuples
# Using author:  Le Bon
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53152 -------------
# Looking up by title and author.
# Using title:  Kertomuksia Intiasta
# Using author:  Kipling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53153 -------------
# Looking up by title and author.
# Using title:  Mehalah
# Using author:  Baring-Gould
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53154 -------------
# Looking up by title and author.
# Using title:  Motor Tours in the West Country
# Using author:  Stawell
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53155 -------------
# Looking up by title and author.
# Using title:  The Religious Thought of the Greeks
# Using author:  Moore
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53156 -------------
# Looking up by title and author.
# Using title:  Gleaning of a Mystic
# Using author:  Heindel
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53157 -------------
# Looking up by title and author.
# Using title:  Valittuja kertomuksia
# Using author:  Kipling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53158 -------------
# Looking up by title and author.
# Using title:  New England Joke Lore
# Using author:  Crandall
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 53159 -------------
# Looking up by title and author.
# Using title:  Piccole anime
# ------------ Processing row 53160 -------------
# Looking up by title and author.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-bf8b9d064705> in <module>()
# ----> 1 lookupStuff(start=52456)
#
# <ipython-input-47-2bed4d649598> in lookupStuff(start)
#      13             print('Looking up by title and author.')
#      14             if row.title is not None:
# ---> 15                 title = sanitizeTitle(row.title)
#      16                 print('Using title: ', title)
#      17             else:
#
# <ipython-input-35-ca9283e85117> in sanitizeTitle(title)
#       1 def sanitizeTitle(title):
#       2     # Grab the first part of the title, before any colon.
# ----> 3     if ':' in title:
#       4         title = title.split(':')[0]
#       5     # If there are quotation marks, remove everything after.
#
# TypeError: argument of type 'float' is not iterable

# %%
df.to_hdf('pg-text-4-dbpedia.hdf', 'pg')
# Out:
# /usr/lib/python3.6/site-packages/pandas/core/generic.py:1282: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block1_values] [items->['LCC', 'author', 'authoryearofbirth', 'authoryearofdeath', 'downloads', 'formats', 'languages', 'lcsh', 'title', 'type', '_repo', '_version', 'alternative_title', 'contributor', 'covers', 'creator', 'description', 'edition_identifiers', 'edition_note', 'gutenberg_bookshelf', 'gutenberg_issued', 'gutenberg_type', 'identifiers', 'jmdate', 'subjects', 'language_note', 'production_note', 'publication_date', 'publication_note', 'publisher', 'rights', 'rights_url', 'series_note', 'summary', 'tableOfContents', 'titlepage_image', 'url', 'wikipedia', 'filename', 'wp_publication_date', 'wp_subjects', 'wp_info', 'wp_literary_genres']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
df[df.wp_subjects.notnull()].wp_subjects.loc[11]
# Out:
# "['Fictional_subterranea', 'Alice_in_Wonderland', 'High_fantasy_novels', '1865_novels', '1860s_fantasy_novels', 'Literature_featuring_anthropomorphic_characters', 'Macmillan_Publishers_books', 'Size_change_in_fiction', 'Animals_in_media', 'British_novels_adapted_into_films', 'D._Appleton_&_Company_books', 'Cultural_depictions_of_Benjamin_Disraeli', 'Novels_adapted_into_radio_programs', 'Novels_adapted_into_television_programs', 'Novels_adapted_into_operas', 'Novels_adapted_into_plays', 'Novels_adapted_into_comics']"

# %%
allSubjs = []
for i, row in df.iterrows(): 
    subjs = row['subjects']
    try: 
        subjs = literal_eval(subjs)
    except: 
        continue
    for subj in subjs: 
        allSubjs.append(subj)
    if type(row.wp_subjects) == list: 
        for subj in row.wp_subjects: 
            allSubjs.append(subj)

# %%
allWPSubjs = []
for i, row in df.iterrows(): 
    subjs = row['wp_subjects']
    try: 
        subjs = literal_eval(subjs)
    except: 
        continue
    for subj in subjs: 
        allWPSubjs.append(subj)

# %%
Counter(allWPSubjs).most_common(50)
# Out:
# [('Novels_first_published_in_serial_form', 247),
#  ('British_novels_adapted_into_films', 109),
#  ('19th-century_American_novels', 99),
#  ('Victorian_novels', 96),
#  ('British_novels', 93),
#  ('Novels_adapted_into_plays', 92),
#  ('English_novels', 88),
#  ('20th-century_American_novels', 85),
#  ('American_science_fiction_novels', 63),
#  ('American_novels_adapted_into_films', 59),
#  ('19th-century_novels', 58),
#  ('Historical_novels', 57),
#  ('Debut_novels', 51),
#  ('Novels_set_in_London', 47),
#  ('1910s_fantasy_novels', 44),
#  ("American_children's_novels", 42),
#  ('Harper_&_Brothers_books', 41),
#  ('Macmillan_Publishers_books', 40),
#  ('American_fantasy_novels', 40),
#  ('1915_novels', 39),
#  ('Novels_by_H._Rider_Haggard', 39),
#  ('Chapman_&_Hall_books', 38),
#  ('Gothic_novels', 37),
#  ('Novels_adapted_into_comics', 36),
#  ('Novels_adapted_into_films', 36),
#  ('Picaresque_novels', 36),
#  ('Novels_adapted_into_television_programs', 34),
#  ("British_children's_novels", 34),
#  ('Novels_about_orphans', 33),
#  ("Children's_fantasy_novels", 32),
#  ('Novels_set_on_islands', 32),
#  ('Works_published_under_a_pseudonym', 31),
#  ('1908_novels', 30),
#  ('Novels_by_Jules_Verne', 29),
#  ('Oz_(franchise)_books', 28),
#  ('Novels_set_in_England', 28),
#  ('Literature_featuring_anthropomorphic_characters', 27),
#  ('Novels_by_H._G._Wells', 27),
#  ('Novels_by_Anthony_Trollope', 27),
#  ('1911_novels', 26),
#  ('1900s_fantasy_novels', 26),
#  ('Novels_by_Walter_Scott', 26),
#  ('Novels_set_in_Paris', 26),
#  ('Fantasy_short_story_collections', 26),
#  ('Sequel_novels', 25),
#  ('1913_novels', 25),
#  ('British_science_fiction_novels', 25),
#  ('1917_novels', 25),
#  ('1912_novels', 25),
#  ('Novels_by_Charles_Dickens', 25)]

# %%
Counter(allSubjs).most_common(50)
# Out:
# [('Fiction', 53),
#  ('French literature', 31),
#  ('Science fiction', 19),
#  ('Poetry', 16),
#  ('Love stories', 16),
#  ('Adventure stories', 16),
#  ('Short stories', 15),
#  ('Didactic fiction', 13),
#  ('Classical literature', 13),
#  ('Historical fiction', 12),
#  ('Fantasy fiction', 12),
#  ('Psychological fiction', 11),
#  ('England -- Fiction', 11),
#  ('Western stories', 11),
#  ('Detective and mystery stories', 10),
#  ('Triangles (Interpersonal relations) -- Fiction', 8),
#  ('Essays', 8),
#  ('Humorous stories', 8),
#  ('Domestic fiction', 7),
#  ('Young women -- Fiction', 7),
#  ('Pastoral fiction', 6),
#  ('Bildungsromans', 6),
#  ('Orphans -- Fiction', 6),
#  ('Wessex (England) -- Fiction', 5),
#  ('War stories', 5),
#  ('Mars (Planet) -- Fiction', 5),
#  ('London (England) -- Fiction', 5),
#  ('Farm life -- Fiction', 4),
#  ('Brothers and sisters -- Fiction', 4),
#  ('Religion', 4),
#  ('Revenge -- Fiction', 4),
#  ('Tarzan (Fictitious character) -- Fiction', 4),
#  ('Satire', 4),
#  ('Married people -- Fiction', 4),
#  ('Sea stories', 4),
#  ('Country life -- Fiction', 4),
#  ('Short stories, American', 4),
#  ('Women farmers -- Fiction', 3),
#  ('Women immigrants -- Fiction', 3),
#  ('Political statistics -- Handbooks, manuals, etc.', 3),
#  ('Political science -- Handbooks, manuals, etc.', 3),
#  ('World politics -- Handbooks, manuals, etc.', 3),
#  ('Geography -- Handbooks, manuals, etc.', 3),
#  ('Clergy -- Fiction', 3),
#  ('Illegitimate children -- Fiction', 3),
#  ('Married women -- Fiction', 3),
#  ('Adultery -- Fiction', 3),
#  ('Time travel -- Fiction', 3),
#  ('Computer science', 3),
#  ('Horror tales', 3)]

# %%
len(df[df['wp_info'].notnull()])
# Out:
# 1898

# %%
df = df.rename(columns={"subjects": "wikiSubjects"})

# %%
df.to_sql('pg', conn, if_exists='append')
