# %%
import pandas as pd
import glob
import os
import gutenberg
from gutenberg.cleanup import strip_headers
import sqlite3 as sql
import requests
import urllib
import json
from collections import Counter
from ast import literal_eval

# %%
conn = sql.connect('pg-pr-eng.db')
c = conn.cursor()

# %%
df = pd.read_sql('select `id`, `title_prEng`, `author`, `wikipedia` from pg', conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1400             else:
# -> 1401                 cur.execute(*args)
#    1402             return cur
#
# OperationalError: no such table: pg
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-3-3fa80bd86939> in <module>()
# ----> 1 df = pd.read_sql('select `id`, `title_prEng`, `author`, `wikipedia` from pg', conn)
#
# /usr/lib/python3.6/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     397             sql, index_col=index_col, params=params,
#     398             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 399             chunksize=chunksize)
#     400
#     401     try:
#
# /usr/lib/python3.6/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1434
#    1435         args = _convert_params(sql, params)
# -> 1436         cursor = self.execute(*args)
#    1437         columns = [col_desc[0] for col_desc in cursor.description]
#    1438
#
# /usr/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1411             ex = DatabaseError(
#    1412                 "Execution failed on sql '%s': %s" % (args[0], exc))
# -> 1413             raise_with_traceback(ex)
#    1414
#    1415     @staticmethod
#
# /usr/lib/python3.6/site-packages/pandas/compat/__init__.py in raise_with_traceback(exc, traceback)
#     338         if traceback == Ellipsis:
#     339             _, _, traceback = sys.exc_info()
# --> 340         raise exc.with_traceback(traceback)
#     341 else:
#     342     # this version of raise is a syntax error in Python 3
#
# /usr/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1399                 cur.execute(*args, **kwargs)
#    1400             else:
# -> 1401                 cur.execute(*args)
#    1402             return cur
#    1403         except Exception as exc:
#
# DatabaseError: Execution failed on sql 'select `id`, `title_prEng`, `author`, `wikipedia` from pg': no such table: pg

# %%
class DBPedia(): 
    """ Looks up metadata about a book from DBPedia, 
    using fuzzy matching on the title and author. """
    def __init__(self, title=None, author=None, resource=None):
        if resource==None and (title==None or author==None): 
            print('Must specify either the resource URI stub, or title and author.')
            raise
        if resource is not None: 
            resource = urllib.parse.unquote(resource)
            self.resourceURI = "http://dbpedia.org/resource/" + resource
        else: 
            response = self.getMeta(title, author)
            parsed = self.parseMeta(response)
            self.resourceURI = self.getResourceURI(parsed)
    
        if self.resourceURI is not None: 
            resourceResponse = self.queryDBP(self.resourceURI)
            resourceParsed = self.parseMeta(resourceResponse)
            self.info = self.getInfo(resourceParsed)
            if self.info is not None: 
                self.pubDate = self.getPubDate()
                self.subjects = self.getSubjects()
                self.literaryGenres = self.getLiteraryGenres()
            else: 
                self._abort()
        else: 
            self._abort()
        
    def _abort(self): 
        self.info = None 
        self.pubDate = None
        self.subjects = None
        self.literaryGenres = None
    
    def getMeta(self, title, author): 
        query = """select distinct ?book
                where {
                  # ?book a dbo:Book .
                  # ?book dbo:author ?author .
                  # ?book dbp:name ?name .
                  FILTER (regex(?name, "%s"))
                  FILTER (regex(?author, "%s"))
                } 
                LIMIT 100""" % (title, author)
        response = requests.get("http://dbpedia.org/sparql", 
                                params=[('query', query), 
                                        ('format', 'application/json')])
        return response

    def parseMeta(self, dbpResponse): 
        try: 
            parsed = json.loads(dbpResponse.text)
        except: 
            print("Couldn't decode JSON: ", dbpResponse.text)
            return None
        return parsed

    def getResourceURI(self, jsonMeta): 
        try: 
            bindings = jsonMeta['results']['bindings']
        except KeyError: 
            print("Couldn't find the appropriate results in the JSON: ", jsonMeta)
            return None
        try: 
            uri = bindings[0]['book']['value']
        except IndexError: 
            print("Couldn't find a resource URI. There is no 0th element in the JSON: ", jsonMeta)
            return None
        return uri
    
    def queryDBP(self, resourceURI):
        query = 'DESCRIBE <%s>' % resourceURI
        params = [('default-graph-uri', 'http://dbpedia.org'), 
                  ('query', query), ('format', 'application/json')]
        r = requests.get("http://dbpedia.org/sparql", params=params)
        return r

    def getInfo(self, jsonData):
        try: 
            data = jsonData[self.resourceURI]
            return data
        except KeyError: 
            print('Strangely, there is no entry in items for this item. Jsondata: ', jsonData)
        
    
    def getPubDate(self): 
        try: 
            releaseDate = self.info['http://dbpedia.org/ontology/releaseDate']
        except KeyError: 
            print('No releaseDate in self.info ontology. Trying property.')
            print('Available info: ', self.info.keys())
            try: 
                releaseDate = self.info['http://dbpedia.org/property/releaseDate']
            except KeyError: 
                print('No releaseDate in self.info property. Giving up.')
                return None
        try: 
            firstRelease = releaseDate[0]
        except IndexError: 
            print('There is no 0th release, apparently: ', releaseDate)
            return None
        try: 
            date = firstRelease['value']
        except KeyError: 
            print('Strangely, no actual date in releaseDate:', releaseDate)
            return None
        return date
    
    def getSubjects(self): 
        subjects = []
        try: 
            subjs = self.info['http://purl.org/dc/terms/subject']
        except KeyError: 
            print('No subject in self.info.')
            return None
        for subj in subjs: 
            subject = subj['value'].split('/')[-1]
            if subject.startswith('Category:'): 
                subject = subject[9:]
            subjects.append(subject)
        return subjects
    
    def getLiteraryGenres(self): 
        literaryGenres = []
        try: 
            genres = self.info['http://dbpedia.org/ontology/literaryGenre']
        except KeyError: 
            print('No literary genre in self.info.')
            return None
        for genre in genres: 
            literaryGenre = genre['value'].split('/')[-1]
            literaryGenres.append(literaryGenre)
        return literaryGenres

# %%
uly = DBPedia('Ulysses', 'Joyce')

# %%
pp = DBPedia("Pilgrim's Progress", "Bunyan")
# Out:
# No releaseDate in self.info ontology. Trying property.
# Available info:  dict_keys(['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#comment', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/prov#wasDerivedFrom', 'http://dbpedia.org/ontology/abstract', 'http://dbpedia.org/ontology/author', 'http://xmlns.com/foaf/0.1/name', 'http://dbpedia.org/property/name', 'http://xmlns.com/foaf/0.1/depiction', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', 'http://dbpedia.org/ontology/thumbnail', 'http://purl.org/dc/terms/subject', 'http://dbpedia.org/ontology/wikiPageID', 'http://dbpedia.org/ontology/wikiPageRevisionID', 'http://dbpedia.org/ontology/wikiPageExternalLink', 'http://dbpedia.org/property/author'])
# No releaseDate in self.info property. Giving up.

# %%
df
# Out:
#          id                                        title_prEng  \
# 0       100          The Complete Works of William Shakespeare
# 1     10002                        The House on the Borderland
# 2     10007                                           Carmilla
# 3     10021                                        Tenterhooks
# 4     10029                              The Hunt Ball Mystery
# 5     10039                The Works of Aphra Behn, Volume III
# 6     10046                              Salute to Adventurers
# 7     10049  Old Lady Mary: A Story of the Seen and the Unseen
# 8     10050  A Little Pilgrim: Stories of the Seen and the ...
# 9     10051  The Little Pilgrim: Further Experiences.: Stor...
# 10    10052  The Open Door, and the Portrait.: Stories of t...
# 11    10057                            The Secret of the Tower
# 12    10064                                  Beltane the Smith
# 13    10076                           Lister's Great Adventure
# 14    10082                              The Hampstead Mystery
# 15    10089                                   Elves and Heroes
# 16    10095          The Twilight of the Gods, and Other Tales
# 17    10100                                              Byron
# 18    10102       The Czar's Spy: The Mystery of a Silent Love
# 19    10110                          The Postmaster's Daughter
# 20    10111                      Boys and Girls from Thackeray
# 21    10119                                            Adonais
# 22    10122                              Fairies and Fusiliers
# 23    10125                   The Best Letters of Charles Lamb
# 24     1013                          The First Men in the Moon
# 25    10132                                         The Sowers
# 26    10133          The Vigil of Venus and Other Poems by "Q"
# 27    10148                 The Merry Adventures of Robin Hood
# 28    10150                                    Dracula's Guest
# 29    10161            English Poets of the Eighteenth Century
# ...     ...                                                ...
# 6934  50856  Charles Tyrrell; or, The Bitter Blood. Volumes...
# 6935  50858         Heidelberg: A Romance. Volumes I, II & III
# 6936  50906      Savrola: A Tale of the Revolution in Laurania
# 6937  50943                Rose D'Albret; or, Troublous Times.
# 6938  50964               Leonora D'Orco: A Historical Romance
# 6939  51015                     Moral Poison in Modern Fiction
# 6940  51164                                The Convict: A Tale
# 6941  51174  The Man in Black: An Historical Novel of the D...
# 6942  51251      Morley Ernstein; or, the Tenants of the Heart
# 6943  51352                               Agnes Sorel: A Novel
# 6944  51425                 The Autobiography of a Super-Tramp
# 6945  51455                 The Fate: A Tale of Stirring Times
# 6946  51497                       Tales from the Telling-House
# 6947  51557  The Colloquies of Edward Osborne, Citizen and ...
# 6948  51628            Delaware; or, The Ruined Family. Vol. 1
# 6949  51629            Delaware; or, The Ruined Family. Vol. 2
# 6950  51630            Delaware; or, The Ruined Family. Vol. 3
# 6951  51652  The Works of John Dryden, now first collected ...
# 6952  51665           Tippoo Sultaun: A tale of the Mysore war
# 6953  51715  A Whim, and Its Consequences: Collection of Br...
# 6954  51815  Henry Smeaton: A Jacobite Story of the Reign o...
# 6955  51898                          Beauchamp; or, The Error.
# 6956  52020                            Roland Whately: A Novel
# 6957  52375                  Blue-Stocking Hall, (Vol. 2 of 3)
# 6958  52501                          The First Men in the Moon
# 6959  52620  An English Garner: Ingatherings from Our Histo...
# 6960  52924      The Colleen Bawn; or, the Brides of Garryowen
# 6961  52928                         The Poetry of South Africa
# 6962  53206  Selections from Modern Poets: Made by J. C. Sq...
# 6963  53455            Rank and Talent; A Novel, Vol. 1 (of 3)
#
#                                         author  \
# 0                         Shakespeare, William
# 1                        Hodgson, William Hope
# 2                     Le Fanu, Joseph Sheridan
# 3                                Leverson, Ada
# 4                         Magnay, William, Sir
# 5                                  Behn, Aphra
# 6                                 Buchan, John
# 7                    Oliphant, Mrs. (Margaret)
# 8                    Oliphant, Mrs. (Margaret)
# 9                    Oliphant, Mrs. (Margaret)
# 10                   Oliphant, Mrs. (Margaret)
# 11                               Hope, Anthony
# 12                             Farnol, Jeffery
# 13                            Bindloss, Harold
# 14                 Watson, John R. (John Reay)
# 15     Mackenzie, Donald A. (Donald Alexander)
# 16                            Garnett, Richard
# 17                                Nichol, John
# 18                           Le Queux, William
# 19                                Tracy, Louis
# 20                    Sweetser, Kate Dickinson
# 21                       Shelley, Percy Bysshe
# 22                              Graves, Robert
# 23                               Lamb, Charles
# 24               Wells, H. G. (Herbert George)
# 25                       Merriman, Henry Seton
# 26                       Quiller-Couch, Arthur
# 27                                Pyle, Howard
# 28                                Stoker, Bram
# 29                                        None
# ...                                        ...
# 6934  James, G. P. R. (George Payne Rainsford)
# 6935  James, G. P. R. (George Payne Rainsford)
# 6936                        Churchill, Winston
# 6937  James, G. P. R. (George Payne Rainsford)
# 6938  James, G. P. R. (George Payne Rainsford)
# 6939    Johnson, R. Brimley (Reginald Brimley)
# 6940  James, G. P. R. (George Payne Rainsford)
# 6941  James, G. P. R. (George Payne Rainsford)
# 6942  James, G. P. R. (George Payne Rainsford)
# 6943  James, G. P. R. (George Payne Rainsford)
# 6944             Davies, W. H. (William Henry)
# 6945  James, G. P. R. (George Payne Rainsford)
# 6946      Blackmore, R. D. (Richard Doddridge)
# 6947                             Manning, Anne
# 6948  James, G. P. R. (George Payne Rainsford)
# 6949  James, G. P. R. (George Payne Rainsford)
# 6950  James, G. P. R. (George Payne Rainsford)
# 6951                              Dryden, John
# 6952                           Taylor, Meadows
# 6953  James, G. P. R. (George Payne Rainsford)
# 6954  James, G. P. R. (George Payne Rainsford)
# 6955  James, G. P. R. (George Payne Rainsford)
# 6956                               Waugh, Alec
# 6957                    Scargill, William Pitt
# 6958             Wells, H. G. (Herbert George)
# 6959                                      None
# 6960                          Boucicault, Dion
# 6961                                      None
# 6962                                      None
# 6963                    Scargill, William Pitt
#
#                                               wikipedia  releaseDate  subjects
# 0                                                  None          NaN       NaN
# 1     ['https://fr.wikipedia.org/wiki/La_Maison_au_b...          NaN       NaN
# 2     ['https://fr.wikipedia.org/wiki/Carmilla', 'ht...          NaN       NaN
# 3                                                  None          NaN       NaN
# 4                                                  None          NaN       NaN
# 5                                                  None          NaN       NaN
# 6                                                  None          NaN       NaN
# 7                                                  None          NaN       NaN
# 8                                                  None          NaN       NaN
# 9                                                  None          NaN       NaN
# 10                                                 None          NaN       NaN
# 11                                                 None          NaN       NaN
# 12                                                 None          NaN       NaN
# 13                                                 None          NaN       NaN
# 14                                                 None          NaN       NaN
# 15                                                 None          NaN       NaN
# 16    ['https://en.wikipedia.org/wiki/The_Twilight_o...          NaN       NaN
# 17                                                 None          NaN       NaN
# 18                                                 None          NaN       NaN
# 19                                                 None          NaN       NaN
# 20                                                 None          NaN       NaN
# 21                                                 None          NaN       NaN
# 22                                                 None          NaN       NaN
# 23                                                 None          NaN       NaN
# 24    ['https://fi.wikipedia.org/wiki/Ensimm%C3%A4is...          NaN       NaN
# 25                                                 None          NaN       NaN
# 26                                                 None          NaN       NaN
# 27                                                 None          NaN       NaN
# 28                                                 None          NaN       NaN
# 29                                                 None          NaN       NaN
# ...                                                 ...          ...       ...
# 6934                                               None          NaN       NaN
# 6935                                               None          NaN       NaN
# 6936                                               None          NaN       NaN
# 6937                                               None          NaN       NaN
# 6938                                               None          NaN       NaN
# 6939                                               None          NaN       NaN
# 6940                                               None          NaN       NaN
# 6941                                               None          NaN       NaN
# 6942                                               None          NaN       NaN
# 6943                                               None          NaN       NaN
# 6944                                               None          NaN       NaN
# 6945                                               None          NaN       NaN
# 6946                                               None          NaN       NaN
# 6947                                               None          NaN       NaN
# 6948                                               None          NaN       NaN
# 6949                                               None          NaN       NaN
# 6950                                               None          NaN       NaN
# 6951                                               None          NaN       NaN
# 6952                                               None          NaN       NaN
# 6953                                               None          NaN       NaN
# 6954                                               None          NaN       NaN
# 6955                                               None          NaN       NaN
# 6956                                               None          NaN       NaN
# 6957                                               None          NaN       NaN
# 6958                                               None          NaN       NaN
# 6959                                               None          NaN       NaN
# 6960                                               None          NaN       NaN
# 6961                                               None          NaN       NaN
# 6962                                               None          NaN       NaN
# 6963                                               None          NaN       NaN
#
# [6964 rows x 6 columns]

# %%
twi = DBPedia(resource="The_Twilight_of_the_Gods_and_Other_Tales")

# %%
def getResource(wikiPagesRaw): 
    try: 
        wikiList = literal_eval(wikiPagesRaw)
    except ValueError: 
        return None
    for item in wikiList: 
        if 'en.wikipedia.org' in item: 
            return item.split('/')[-1]
    return None

# %%
def sanitizeTitle(title): 
    # Grab the first part of the title, before any colon. 
    if ':' in title: 
        title = title.split(':')[0]
    # If there are quotation marks, remove everything after. 
    if '"' in title: 
        title = title.split('"')[0]
    return title

# %%
def lookupStuff(start=0):
    times = 0
    for i, row in df.iterrows(): 
        if i<start: 
            continue
        print('------------ Processing row %s -------------' % i)
        resource = getResource(row.wikipedia)
        times += 1
        if resource is not None: 
            print('Getting resource: ', resource)
            book = DBPedia(resource=resource)
        else: 
            print('Looking up by title and author.')
            title = sanitizeTitle(row.title_prEng)
            print('Using title: ', title)
            author = row.author
            if author is not None: 
                author = row.author.split(',')[0]
                print('Using author: ', author)
                book = DBPedia(title = title, author=author)
        if book is not None: 
            pubdate = book.pubDate
            print('Pubdate: ', pubdate)
            df.set_value(i, 'releaseDate', pubdate)
            subjects = book.subjects
            print('Subjects: ', subjects)
            if subjects is not None: 
                df.set_value(i, 'subjects', str(subjects))
            literaryGenres = book.literaryGenres
            print('Literary genres: ', literaryGenres)
            if literaryGenres is not None: 
                df.set_value(i, 'literaryGenres', str(literaryGenres))
            if book.info is not None: 
                df.set_value(i, 'info', str(book.info))

# %%
lookupStuff(start=6330)
# Out:
# ------------ Processing row 6330 -------------
# Looking up by title and author.
# Using title:  Joan of the Sword Hand
# Using author:  Crockett
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6331 -------------
# Looking up by title and author.
# Using title:  A Legend of Reading Abbey
# Using author:  MacFarlane
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6332 -------------
# Looking up by title and author.
# Using title:  Byron
# Using author:  Edgcumbe
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6333 -------------
# Looking up by title and author.
# Using title:  The Champagne Standard
# Using author:  Lane
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6334 -------------
# Looking up by title and author.
# Using title:  Phroso
# Using author:  Hope
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6335 -------------
# Looking up by title and author.
# Using title:  Wild Heather
# Using author:  Meade
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6336 -------------
# Looking up by title and author.
# Using title:  General Bounce; Or, The Lady and the Locusts
# Using author:  Whyte-Melville
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6337 -------------
# Looking up by title and author.
# Using title:  The Serf
# Using author:  Thorne
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6338 -------------
# Looking up by title and author.
# Using title:  The Terms of Surrender
# Using author:  Tracy
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6339 -------------
# Looking up by title and author.
# Using title:  The Ornithology of Shakespeare
# Using author:  Harting
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6340 -------------
# Looking up by title and author.
# Using title:  Gold and Incense
# Using author:  Pearse
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6341 -------------
# Looking up by title and author.
# Using title:  Kwan-yin
# Using author:  Benson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6342 -------------
# Looking up by title and author.
# Using title:  The Green Bough
# Using author:  Thurston
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6343 -------------
# Looking up by title and author.
# Using title:  Nestleton Magna
# Using author:  Wray
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6344 -------------
# Looking up by title and author.
# Using title:  The Confounding of Camelia
# Using author:  Sedgwick
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6345 -------------
# Looking up by title and author.
# Using title:  The Maker of Rainbows, and Other Fairy-tales and Fables
# Using author:  Le Gallienne
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6346 -------------
# Looking up by title and author.
# Using title:  A Select Collection of Old English Plays, Volume 11
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6347 -------------
# Looking up by title and author.
# Using title:  A Fair Mystery
# Using author:  Brame
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6348 -------------
# Looking up by title and author.
# Using title:  On Patrol
# Using author:  Bower
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6349 -------------
# Looking up by title and author.
# Using title:  Poems
# Using author:  Jenkins
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6350 -------------
# Looking up by title and author.
# Using title:  The Starling
# Using author:  Macleod
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6351 -------------
# Looking up by title and author.
# Using title:  Pabo, the Priest
# Using author:  Baring-Gould
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6352 -------------
# Looking up by title and author.
# Using title:  Paths of Judgement
# Using author:  Sedgwick
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6353 -------------
# Looking up by title and author.
# Using title:  Salem Chapel, v.1/2
# Using author:  Oliphant
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6354 -------------
# Looking up by title and author.
# Using title:  Studies of Contemporary Poets
# Using author:  Sturgeon
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6355 -------------
# Looking up by title and author.
# Using title:  Salem Chapel, v. 2/2
# Using author:  Oliphant
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6356 -------------
# Looking up by title and author.
# Using title:  The Curate in Charge
# Using author:  Oliphant
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6357 -------------
# Looking up by title and author.
# Using title:  Akra the Slave
# Using author:  Gibson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6358 -------------
# Looking up by title and author.
# Using title:  The Golden Helm, and Other Verse
# Using author:  Gibson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6359 -------------
# Looking up by title and author.
# Using title:  The Red Window
# Using author:  Hume
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6360 -------------
# Looking up by title and author.
# Using title:  English Narrative Poems
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6361 -------------
# Looking up by title and author.
# Using title:  Memoirs of the Life of Sir Walter Scott, Volume 4 (of 10)
# Using author:  Lockhart
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6362 -------------
# Looking up by title and author.
# Using title:  The Tyranny of Tears
# Using author:  Chambers
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6363 -------------
# Looking up by title and author.
# Using title:  The Letters of Jane Austen
# Using author:  Austen
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6364 -------------
# Looking up by title and author.
# Using title:  Chaucer's Translation of Boethius's
# Using author:  Boethius
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6365 -------------
# Looking up by title and author.
# Using title:  A Bachelor Husband
# Using author:  Ayres
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6366 -------------
# Looking up by title and author.
# Using title:  Memoirs of a Surrey Labourer
# Using author:  Sturt
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6367 -------------
# Looking up by title and author.
# Using title:  Morag
# Using author:  Rae
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6368 -------------
# Looking up by title and author.
# Using title:  The Eve of All-Hallows; Or, Adelaide of Tyrconnel, v. 2 of 3
# Using author:  Hartstonge
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6369 -------------
# Looking up by title and author.
# Using title:  Faces in the Fire, and Other Fancies
# Using author:  Boreham
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6370 -------------
# Looking up by title and author.
# Using title:  The Dull Miss Archinard
# Using author:  Sedgwick
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6371 -------------
# Looking up by title and author.
# Using title:  Armorel of Lyonesse
# Using author:  Besant
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6372 -------------
# Looking up by title and author.
# Using title:  Rebel women
# Using author:  Sharp
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6373 -------------
# Looking up by title and author.
# Using title:  The Making of a Prig
# Using author:  Sharp
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6374 -------------
# Looking up by title and author.
# Using title:  Poetry
# Using author:  Oldham
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6375 -------------
# Looking up by title and author.
# Using title:  The Rescue
# Using author:  Sedgwick
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6376 -------------
# Looking up by title and author.
# Using title:  With the King at Oxford
# Using author:  Church
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6377 -------------
# Looking up by title and author.
# Using title:  The Shadow of Ashlydyat
# Using author:  Wood
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6378 -------------
# Looking up by title and author.
# Using title:  The World of H.G. Wells
# Using author:  Brooks
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6379 -------------
# Looking up by title and author.
# Using title:  Double Harness
# Using author:  Hope
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6380 -------------
# Looking up by title and author.
# Using title:  A Child's Dream of a Star
# Using author:  Dickens
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6381 -------------
# Looking up by title and author.
# Using title:  The Third Window
# Using author:  Sedgwick
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6382 -------------
# Looking up by title and author.
# Using title:  The Retrospect
# Using author:  Cambridge
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6383 -------------
# Looking up by title and author.
# Using title:  Love Among the Ruins
# Using author:  Deeping
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6384 -------------
# Looking up by title and author.
# Using title:  Abbotsford
# Using author:  Anonymous
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6385 -------------
# Looking up by title and author.
# Using title:  The Duchess of Trajetto
# Using author:  Manning
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6386 -------------
# Looking up by title and author.
# Using title:  The History of Johnny Quæ Genus, the Little Foundling of the Late Doctor Syntax.
# Using author:  Combe
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6387 -------------
# Looking up by title and author.
# Using title:  Poems
# Using author:  Smith
# No releaseDate in self.info ontology. Trying property.
# Available info:  dict_keys(['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#comment', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/prov#wasDerivedFrom', 'http://dbpedia.org/ontology/abstract', 'http://dbpedia.org/ontology/author', 'http://dbpedia.org/ontology/literaryGenre', 'http://dbpedia.org/ontology/mediaType', 'http://dbpedia.org/ontology/numberOfPages', 'http://dbpedia.org/ontology/publisher', 'http://xmlns.com/foaf/0.1/name', 'http://dbpedia.org/property/name', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', 'http://purl.org/dc/terms/subject', 'http://dbpedia.org/ontology/wikiPageID', 'http://dbpedia.org/ontology/wikiPageRevisionID', 'http://dbpedia.org/property/author', 'http://dbpedia.org/property/genre', 'http://dbpedia.org/property/mediaType', 'http://dbpedia.org/property/pages', 'http://dbpedia.org/property/publisher'])
# No releaseDate in self.info property. Giving up.
# Pubdate:  None
# Subjects:  ['1971_books', 'American_poetry_collections']
# Literary genres:  ['Poetry']
# ------------ Processing row 6388 -------------
# Looking up by title and author.
# Using title:  The Shadow of a Sin
# Using author:  Brame
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6389 -------------
# Looking up by title and author.
# Using title:  Frankenstein; Or, The Modern Prometheus
# Using author:  Shelley
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6390 -------------
# Looking up by title and author.
# Using title:  The Sorrows of Satan
# Using author:  Corelli
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6391 -------------
# Looking up by title and author.
# Using title:  The Adventure of Princess Sylvia
# Using author:  Williamson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6392 -------------
# Looking up by title and author.
# Using title:  Hugh Walpole
# Using author:  Hergesheimer
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6393 -------------
# Looking up by title and author.
# Using title:  The Pirate
# Using author:  Scott
# No releaseDate in self.info ontology. Trying property.
# Available info:  dict_keys(['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#comment', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/prov#wasDerivedFrom', 'http://dbpedia.org/ontology/abstract', 'http://dbpedia.org/ontology/author', 'http://dbpedia.org/ontology/language', 'http://dbpedia.org/ontology/literaryGenre', 'http://dbpedia.org/ontology/mediaType', 'http://dbpedia.org/ontology/previousWork', 'http://dbpedia.org/ontology/series', 'http://dbpedia.org/ontology/subsequentWork', 'http://xmlns.com/foaf/0.1/name', 'http://dbpedia.org/property/name', 'http://xmlns.com/foaf/0.1/depiction', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', 'http://dbpedia.org/ontology/thumbnail', 'http://purl.org/dc/terms/subject', 'http://dbpedia.org/ontology/wikiPageID', 'http://dbpedia.org/ontology/wikiPageRevisionID', 'http://dbpedia.org/ontology/wikiPageExternalLink', 'http://dbpedia.org/property/precededBy', 'http://dbpedia.org/property/author', 'http://dbpedia.org/property/followedBy', 'http://dbpedia.org/property/genre', 'http://dbpedia.org/property/language', 'http://dbpedia.org/property/mediaType', 'http://dbpedia.org/property/series'])
# No releaseDate in self.info property. Giving up.
# Pubdate:  None
# Subjects:  ['Shetland', 'Pirate_books', 'Historical_novels', 'Novels_by_Walter_Scott', 'Novels_set_on_islands', 'Novels_set_in_Scotland']
# Literary genres:  ['Historical_fiction']
# ------------ Processing row 6394 -------------
# Looking up by title and author.
# Using title:  Sarchedon
# Using author:  Whyte-Melville
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6395 -------------
# Looking up by title and author.
# Using title:  The Circle
# Using author:  Maugham
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6396 -------------
# Looking up by title and author.
# Using title:  Misrepresentative Women
# Using author:  Graham
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6397 -------------
# Looking up by title and author.
# Using title:  Adrienne Toner
# Using author:  Sedgwick
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6398 -------------
# Looking up by title and author.
# Using title:  The Mystery of the Sea
# Using author:  Stoker
# No releaseDate in self.info ontology. Trying property.
# Available info:  dict_keys(['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#comment', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/prov#wasDerivedFrom', 'http://dbpedia.org/ontology/abstract', 'http://dbpedia.org/ontology/author', 'http://dbpedia.org/ontology/publisher', 'http://xmlns.com/foaf/0.1/name', 'http://dbpedia.org/property/name', 'http://xmlns.com/foaf/0.1/depiction', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', 'http://dbpedia.org/ontology/thumbnail', 'http://purl.org/dc/terms/subject', 'http://dbpedia.org/ontology/wikiPageID', 'http://dbpedia.org/ontology/wikiPageRevisionID', 'http://dbpedia.org/ontology/wikiPageExternalLink', 'http://dbpedia.org/property/author', 'http://dbpedia.org/property/publisher'])
# No releaseDate in self.info property. Giving up.
# No literary genre in self.info.
# Pubdate:  None
# Subjects:  ['Doubleday,_Page_&_Company_books', 'Novels_by_Bram_Stoker', '1902_novels']
# Literary genres:  None
# ------------ Processing row 6399 -------------
# Looking up by title and author.
# Using title:  Bernard Treves's Boots
# Using author:  Clarke
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6400 -------------
# Looking up by title and author.
# Using title:  Barbara Rebell
# Using author:  Lowndes
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6401 -------------
# Looking up by title and author.
# Using title:  Literary Celebrities of the English Lake-District
# Using author:  Sessions
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6402 -------------
# Looking up by title and author.
# Using title:  Lady Eureka; or, The Mystery
# Using author:  Williams
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6403 -------------
# Looking up by title and author.
# Using title:  Lady Eureka; or, The Mystery
# Using author:  Williams
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6404 -------------
# Looking up by title and author.
# Using title:  Lady Eureka; or, The Mystery
# Using author:  Williams
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6405 -------------
# Looking up by title and author.
# Using title:  Miracle Gold
# Using author:  Dowling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6406 -------------
# Looking up by title and author.
# Using title:  Miracle Gold
# Using author:  Dowling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6407 -------------
# Looking up by title and author.
# Using title:  Miracle Gold
# Using author:  Dowling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6408 -------------
# Looking up by title and author.
# Using title:  Blackthorn Farm
# Using author:  Applin
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6409 -------------
# Looking up by title and author.
# Using title:  A Marriage Under the Terror
# Using author:  Wentworth
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6410 -------------
# Looking up by title and author.
# Using title:  God and the King
# Using author:  Bowen
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6411 -------------
# Looking up by title and author.
# Using title:  Box and Cox
# Using author:  Morton
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6412 -------------
# Looking up by title and author.
# Using title:  Dariel
# Using author:  Blackmore
# No releaseDate in self.info ontology. Trying property.
# Available info:  dict_keys(['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#comment', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/prov#wasDerivedFrom', 'http://dbpedia.org/ontology/abstract', 'http://dbpedia.org/ontology/author', 'http://xmlns.com/foaf/0.1/name', 'http://dbpedia.org/property/name', 'http://xmlns.com/foaf/0.1/depiction', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', 'http://dbpedia.org/ontology/thumbnail', 'http://purl.org/dc/terms/subject', 'http://dbpedia.org/ontology/wikiPageID', 'http://dbpedia.org/ontology/wikiPageRevisionID', 'http://dbpedia.org/property/author'])
# No releaseDate in self.info property. Giving up.
# No literary genre in self.info.
# Pubdate:  None
# Subjects:  ['1897_novels', 'Novels_by_Richard_Doddridge_Blackmore', 'Novels_set_in_Surrey']
# Literary genres:  None
# ------------ Processing row 6413 -------------
# Looking up by title and author.
# Using title:  The Honey-Pot
# Using author:  Barcynska
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6414 -------------
# Looking up by title and author.
# Using title:  Yonder
# Using author:  Young
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6415 -------------
# Looking up by title and author.
# Using title:  Lost Diaries
# Using author:  Baring
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6416 -------------
# Looking up by title and author.
# Using title:  By the Barrow River, and Other Stories
# Using author:  Leamy
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6417 -------------
# Looking up by title and author.
# Using title:  The Spook Ballads
# Using author:  Parkes
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6418 -------------
# Looking up by title and author.
# Using title:  The Cornish Fishermen's Watch-Night, and Other Stories
# Using author:  Anonymous
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6419 -------------
# Looking up by title and author.
# Using title:  Private Letters of Edward Gibbon (1753-1794)  Volume 1 (of 2)
# Using author:  Gibbon
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6420 -------------
# Looking up by title and author.
# Using title:  The Ballads & Songs of Derbyshire
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6421 -------------
# Looking up by title and author.
# Using title:  The Last Call
# Using author:  Dowling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6422 -------------
# Looking up by title and author.
# Using title:  The Last Call
# Using author:  Dowling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6423 -------------
# Looking up by title and author.
# Using title:  The Last Call
# Using author:  Dowling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6424 -------------
# Looking up by title and author.
# Using title:  The Duke's Sweetheart
# Using author:  Dowling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6425 -------------
# Looking up by title and author.
# Using title:  Under St Paul's
# Using author:  Dowling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6426 -------------
# Looking up by title and author.
# Using title:  The Shepheard's Calender
# Using author:  Spenser
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6427 -------------
# Looking up by title and author.
# Using title:  The Lady of Lynn
# Using author:  Besant
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6428 -------------
# Looking up by title and author.
# Using title:  Prefaces to Four Seventeenth-Century Romances
# Using author:  Mackenzie
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6429 -------------
# Looking up by title and author.
# Using title:  Poems
# Using author:  Lovell
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6430 -------------
# Looking up by title and author.
# Using title:  The Lonely Stronghold
# Using author:  Reynolds
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6431 -------------
# Looking up by title and author.
# Using title:  Private Letters of Edward Gibbon (1753-1794) Volume 2 (of 2)
# Using author:  Gibbon
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6432 -------------
# Looking up by title and author.
# Using title:  Friends
# Using author:  Gibson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6433 -------------
# Looking up by title and author.
# Using title:  A Jar of Honey from Mount Hybla
# Using author:  Hunt
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6434 -------------
# Looking up by title and author.
# Using title:  Pride and Prejudice
# Using author:  Austen
# Pubdate:  1813-01-28
# Subjects:  ['19th-century_novels', 'Love_stories', 'Novels_set_in_Hertfordshire', '1813_novels', 'British_satirical_novels', 'Pride_and_Prejudice', 'Novels_adapted_into_plays', 'Novels_about_nobility', 'British_novels_adapted_into_films', 'Novels_by_Jane_Austen']
# Literary genres:  ['Novel_of_manners']
# ------------ Processing row 6435 -------------
# Looking up by title and author.
# Using title:  Fires - Book 1
# Using author:  Gibson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6436 -------------
# Looking up by title and author.
# Using title:  Fires - Book 2
# Using author:  Gibson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6437 -------------
# Looking up by title and author.
# Using title:  Fires - Book 3
# Using author:  Gibson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6438 -------------
# Looking up by title and author.
# Using title:  Passing By
# Using author:  Baring
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6439 -------------
# Looking up by title and author.
# Using title:  Overlooked
# Using author:  Baring
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6440 -------------
# Looking up by title and author.
# Using title:  Salomé
# Using author:  Wilde
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6441 -------------
# Looking up by title and author.
# Using title:  King Horn, Floriz and Blauncheflur, The Assumption of Our Lady
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6442 -------------
# Looking up by title and author.
# Using title:  The Works of Christopher Marlowe, Vol. 2 (of 3)
# Using author:  Marlowe
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6443 -------------
# Looking up by title and author.
# Using title:  Stand Fast, Craig-Royston! (Volume I)
# Using author:  Black
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6444 -------------
# Looking up by title and author.
# Using title:  Stand Fast, Craig-Royston! (Volume II)
# Using author:  Black
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6445 -------------
# Looking up by title and author.
# Using title:  Stand Fast, Craig-Royston! (Volume III)
# Using author:  Black
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6446 -------------
# Looking up by title and author.
# Using title:  Tempest-Driven
# Using author:  Dowling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6447 -------------
# Looking up by title and author.
# Using title:  Tempest-Driven
# Using author:  Dowling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6448 -------------
# Looking up by title and author.
# Using title:  Tempest-Driven
# Using author:  Dowling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6449 -------------
# Looking up by title and author.
# Using title:  An Isle of Surrey
# Using author:  Dowling
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6450 -------------
# Looking up by title and author.
# Using title:  Swords Reluctant
# Using author:  Pemberton
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6451 -------------
# Looking up by title and author.
# Using title:  The Young Lovell
# Using author:  Ford
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6452 -------------
# Looking up by title and author.
# ...
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6928 -------------
# Looking up by title and author.
# Using title:  The Infidel
# Using author:  Braddon
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6929 -------------
# Looking up by title and author.
# Using title:  De L'Orme.
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6930 -------------
# Looking up by title and author.
# Using title:  One in a Thousand; or, The Days of Henri Quatre
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6931 -------------
# Looking up by title and author.
# Using title:  Ticonderoga
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6932 -------------
# Looking up by title and author.
# Using title:  Mary of Burgundy; or, The Revolt of Ghent
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6933 -------------
# Looking up by title and author.
# Using title:  The Man-at-Arms; or, Henry De Cerons. Volumes I and II
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6934 -------------
# Looking up by title and author.
# Using title:  Charles Tyrrell; or, The Bitter Blood. Volumes I and II
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6935 -------------
# Looking up by title and author.
# Using title:  Heidelberg
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6936 -------------
# Looking up by title and author.
# Using title:  Savrola
# Using author:  Churchill
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6937 -------------
# Looking up by title and author.
# Using title:  Rose D'Albret; or, Troublous Times.
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6938 -------------
# Looking up by title and author.
# Using title:  Leonora D'Orco
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6939 -------------
# Looking up by title and author.
# Using title:  Moral Poison in Modern Fiction
# Using author:  Johnson
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6940 -------------
# Looking up by title and author.
# Using title:  The Convict
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6941 -------------
# Looking up by title and author.
# Using title:  The Man in Black
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6942 -------------
# Looking up by title and author.
# Using title:  Morley Ernstein; or, the Tenants of the Heart
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6943 -------------
# Looking up by title and author.
# Using title:  Agnes Sorel
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6944 -------------
# Looking up by title and author.
# Using title:  The Autobiography of a Super-Tramp
# Using author:  Davies
# No releaseDate in self.info ontology. Trying property.
# Available info:  dict_keys(['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#comment', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/prov#wasDerivedFrom', 'http://dbpedia.org/ontology/abstract', 'http://dbpedia.org/ontology/author', 'http://dbpedia.org/ontology/isbn', 'http://xmlns.com/foaf/0.1/name', 'http://dbpedia.org/property/name', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', 'http://purl.org/dc/terms/subject', 'http://dbpedia.org/ontology/wikiPageID', 'http://dbpedia.org/ontology/wikiPageRevisionID', 'http://dbpedia.org/ontology/wikiPageExternalLink', 'http://dbpedia.org/property/author', 'http://dbpedia.org/property/isbn'])
# No releaseDate in self.info property. Giving up.
# No literary genre in self.info.
# Pubdate:  None
# Subjects:  ['1908_books', 'British_autobiographical_novels', 'Anglo-Welsh_novels']
# Literary genres:  None
# ------------ Processing row 6945 -------------
# Looking up by title and author.
# Using title:  The Fate
# Using author:  James
# No releaseDate in self.info ontology. Trying property.
# Available info:  dict_keys(['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#comment', 'http://www.w3.org/2000/01/rdf-schema#seeAlso', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/prov#wasDerivedFrom', 'http://dbpedia.org/ontology/abstract', 'http://dbpedia.org/ontology/author', 'http://dbpedia.org/ontology/isbn', 'http://xmlns.com/foaf/0.1/name', 'http://dbpedia.org/property/name', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', 'http://purl.org/dc/terms/subject', 'http://dbpedia.org/ontology/wikiPageID', 'http://dbpedia.org/ontology/wikiPageRevisionID', 'http://dbpedia.org/ontology/wikiPageExternalLink', 'http://dbpedia.org/property/author', 'http://dbpedia.org/property/isbn', 'http://rdvocab.info/RDARelationshipsWEMI/manifestationOfWork'])
# No releaseDate in self.info property. Giving up.
# No literary genre in self.info.
# Pubdate:  None
# Subjects:  ['Climate_change_books', '2006_books', 'Environmental_non-fiction_books']
# Literary genres:  None
# ------------ Processing row 6946 -------------
# Looking up by title and author.
# Using title:  Tales from the Telling-House
# Using author:  Blackmore
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6947 -------------
# Looking up by title and author.
# Using title:  The Colloquies of Edward Osborne, Citizen and Clothworker of London
# Using author:  Manning
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6948 -------------
# Looking up by title and author.
# Using title:  Delaware; or, The Ruined Family. Vol. 1
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6949 -------------
# Looking up by title and author.
# Using title:  Delaware; or, The Ruined Family. Vol. 2
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6950 -------------
# Looking up by title and author.
# Using title:  Delaware; or, The Ruined Family. Vol. 3
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6951 -------------
# Looking up by title and author.
# Using title:  The Works of John Dryden, now first collected in eighteen volumes. Volume 10
# Using author:  Dryden
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6952 -------------
# Looking up by title and author.
# Using title:  Tippoo Sultaun
# Using author:  Taylor
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6953 -------------
# Looking up by title and author.
# Using title:  A Whim, and Its Consequences
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6954 -------------
# Looking up by title and author.
# Using title:  Henry Smeaton
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6955 -------------
# Looking up by title and author.
# Using title:  Beauchamp; or, The Error.
# Using author:  James
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6956 -------------
# Looking up by title and author.
# Using title:  Roland Whately
# Using author:  Waugh
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6957 -------------
# Looking up by title and author.
# Using title:  Blue-Stocking Hall, (Vol. 2 of 3)
# Using author:  Scargill
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6958 -------------
# Looking up by title and author.
# Using title:  The First Men in the Moon
# Using author:  Wells
# No releaseDate in self.info ontology. Trying property.
# Available info:  dict_keys(['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#comment', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/prov#wasDerivedFrom', 'http://dbpedia.org/ontology/abstract', 'http://dbpedia.org/ontology/author', 'http://dbpedia.org/ontology/numberOfPages', 'http://dbpedia.org/ontology/oclc', 'http://dbpedia.org/ontology/previousWork', 'http://dbpedia.org/ontology/subsequentWork', 'http://xmlns.com/foaf/0.1/name', 'http://dbpedia.org/property/name', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', 'http://purl.org/dc/terms/subject', 'http://dbpedia.org/ontology/wikiPageID', 'http://dbpedia.org/ontology/wikiPageRevisionID', 'http://dbpedia.org/ontology/wikiPageExternalLink', 'http://dbpedia.org/property/precededBy', 'http://dbpedia.org/property/author', 'http://dbpedia.org/property/followedBy', 'http://dbpedia.org/property/oclc', 'http://dbpedia.org/property/pages'])
# No releaseDate in self.info property. Giving up.
# No literary genre in self.info.
# Pubdate:  None
# Subjects:  ['Moon_in_fiction', 'British_novels_adapted_into_films', '1900s_science_fiction_novels', 'Plagiarism_controversies', '1901_novels', 'Space_exploration_novels', 'British_science_fiction_novels', 'Novels_by_H._G._Wells']
# Literary genres:  None
# ------------ Processing row 6959 -------------
# Looking up by title and author.
# Using title:  An English Garner
# Pubdate:  None
# Subjects:  ['Moon_in_fiction', 'British_novels_adapted_into_films', '1900s_science_fiction_novels', 'Plagiarism_controversies', '1901_novels', 'Space_exploration_novels', 'British_science_fiction_novels', 'Novels_by_H._G._Wells']
# Literary genres:  None
# ------------ Processing row 6960 -------------
# Looking up by title and author.
# Using title:  The Colleen Bawn; or, the Brides of Garryowen
# Using author:  Boucicault
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6961 -------------
# Looking up by title and author.
# Using title:  The Poetry of South Africa
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6962 -------------
# Looking up by title and author.
# Using title:  Selections from Modern Poets
# Pubdate:  None
# Subjects:  None
# Literary genres:  None
# ------------ Processing row 6963 -------------
# Looking up by title and author.
# Using title:  Rank and Talent; A Novel, Vol. 1 (of 3)
# Using author:  Scargill
# Couldn't find a resource URI. There is no 0th element in the JSON:  {'head': {'link': [], 'vars': ['book']}, 'results': {'distinct': False, 'ordered': True, 'bindings': []}}
# Pubdate:  None
# Subjects:  None
# Literary genres:  None

# %%
allSubjs = []
for i, row in df.iterrows(): 
    subjs = row['subjects']
    try: 
        subjs = literal_eval(subjs)
    except: 
        continue
    for subj in subjs: 
        allSubjs.append(subj)

# %%
Counter(allSubjs).most_common(50)
# Out:
# [('Novels_first_published_in_serial_form', 127),
#  ('British_novels_adapted_into_films', 99),
#  ('Victorian_novels', 95),
#  ('British_novels', 82),
#  ('English_novels', 81),
#  ('Novels_adapted_into_plays', 52),
#  ('Novels_set_in_London', 41),
#  ('Historical_novels', 40),
#  ('Chapman_&_Hall_books', 38),
#  ('Gothic_novels', 38),
#  ('Novels_by_H._Rider_Haggard', 37),
#  ('19th-century_novels', 35),
#  ('Novels_by_Anthony_Trollope', 30),
#  ('Debut_novels', 28),
#  ('Novels_by_H._G._Wells', 27),
#  ('Novels_by_Charles_Dickens', 27),
#  ('Picaresque_novels', 24),
#  ('Novels_by_P._G._Wodehouse', 22),
#  ('Novels_by_Walter_Scott', 22),
#  ('British_science_fiction_novels', 21),
#  ('British_fantasy_novels', 21),
#  ('Macmillan_Publishers_books', 21),
#  ('1890_novels', 21),
#  ('Novels_set_in_England', 20),
#  ('Novels_adapted_into_comics', 19),
#  ('1890s_fantasy_novels', 19),
#  ('Novels_by_Edward_Bulwer-Lytton', 19),
#  ("British_children's_novels", 17),
#  ('Scottish_novels', 16),
#  ('Literature_featuring_anthropomorphic_characters', 16),
#  ('Novels_adapted_into_television_programs', 16),
#  ('Novels_set_in_the_19th_century', 16),
#  ('Works_published_under_a_pseudonym', 16),
#  ('Novels_by_Thomas_Hardy', 15),
#  ('Novels_by_Joseph_Conrad', 15),
#  ('British_adventure_novels', 15),
#  ('1915_novels', 15),
#  ('British_historical_novels', 15),
#  ('Cassell_(publisher)_books', 15),
#  ('Novels_by_George_Gissing', 15),
#  ('Epistolary_novels', 15),
#  ('Novels_by_Robert_Louis_Stevenson', 14),
#  ('Chatto_&_Windus_books', 14),
#  ('1830_novels', 14),
#  ('Hodder_&_Stoughton_books', 13),
#  ('1910_novels', 13),
#  ("19th-century_British_children's_literature", 13),
#  ('Novels_set_in_Ireland', 12),
#  ('Fantasy_novels', 12),
#  ('Fantasy_short_story_collections', 12)]

# %%
df[df['info'].notnull()]
# Out:
#          id                                        title_prEng  \
# 1     10002                        The House on the Borderland
# 2     10007                                           Carmilla
# 16    10095          The Twilight of the Gods, and Other Tales
# 24     1013                          The First Men in the Moon
# 27    10148                 The Merry Adventures of Robin Hood
# 28    10150                                    Dracula's Guest
# 29    10161            English Poets of the Eighteenth Century
# 30    10165   Across the Zodiac: The Story of a Wrecked Record
# 31     1019             Poems by Currer, Ellis, and Acton Bell
# 34     1024                                        The Wrecker
# 36     1028                                      The Professor
# 40    10337                                      Lady into Fox
# 57     1041                              Shakespeare's Sonnets
# 66     1045                                   Venus and Adonis
# 73     1047                                The New Machiavelli
# 77      105                                         Persuasion
# 80     1051  Sartor Resartus: The Life and Opinions of Herr...
# 87    10542  The Boats of the "Glen Carrig": Being an accou...
# 92    10554                                   Right Ho, Jeeves
# 93    10556                          The Old Man in the Corner
# 114    1059                                 The World Set Free
# 130   10662                                     The Night Land
# 135     107                         Far from the Madding Crowd
# 138   10709                                     Prince Zaleski
# 142   10743                                          Moonfleet
# 144    1076                             The Wallet of Kai Lung
# 146   10762                   Impressions of Theophrastus Such
# 147   10763               It Can Be Done: Poems of Inspiration
# 158    1079  The Life and Opinions of Tristram Shandy, Gent...
# 164     108                      The Return of Sherlock Holmes
# ...     ...                                                ...
# 5973  39786                            Beau Brocade: A Romance
# 6038  40264                                  Regiment of Women
# 6132  40729  "Old Scrooge": A Christmas Carol in Five Stave...
# 6156  40882                            Felix Holt, the Radical
# 6219  41178                       "I Believe" and other essays
# 6236  41256                           Memoirs of Emma Courtney
# 6243  41311                                         Five Plays
# 6270  41438                         The Heart of Princess Osra
# 6387  42301                               Poems: Third Edition
# 6393  42389                    The Pirate: Andrew Lang Edition
# 6398  42455                             The Mystery of the Sea
# 6412  42529                        Dariel: A Romance of Surrey
# 6434  42671                                Pride and Prejudice
# 6616  44286                               "If Youth but Knew!"
# 6649  44587          John Inglesant: A Romance (Volume 1 of 2)
# 6650  44588          John Inglesant: A Romance (Volume 2 of 2)
# 6671  44881                              Confessions of a Thug
# 6689  45038            Perlycross: A Tale of the Western Hills
# 6694  45104                                         "Farewell"
# 6758  45839                                            Dracula
# 6790  46156                                   The Maid of Sker
# 6847  47084  Cradock Nowell: A Tale of the New Forest. Vol....
# 6848  47085  Cradock Nowell: A Tale of the New Forest. Vol....
# 6849  47086  Cradock Nowell: A Tale of the New Forest. Vol....
# 6895  49520           Kit and Kitty: A Story of West Middlesex
# 6909  49850  The Tower of London: A Historical Romance, Ill...
# 6944  51425                 The Autobiography of a Super-Tramp
# 6945  51455                 The Fate: A Tale of Stirring Times
# 6958  52501                          The First Men in the Moon
# 6959  52620  An English Garner: Ingatherings from Our Histo...
#
#                                         author  \
# 1                        Hodgson, William Hope
# 2                     Le Fanu, Joseph Sheridan
# 16                            Garnett, Richard
# 24               Wells, H. G. (Herbert George)
# 27                                Pyle, Howard
# 28                                Stoker, Bram
# 29                                        None
# 30                                 Greg, Percy
# 31                           Brontë, Charlotte
# 34                             Osbourne, Lloyd
# 36                           Brontë, Charlotte
# 40                              Garnett, David
# 57                        Shakespeare, William
# 66                        Shakespeare, William
# 73               Wells, H. G. (Herbert George)
# 77                                Austen, Jane
# 80                             Carlyle, Thomas
# 87                       Hodgson, William Hope
# 92         Wodehouse, P. G. (Pelham Grenville)
# 93              Orczy, Emmuska Orczy, Baroness
# 114              Wells, H. G. (Herbert George)
# 130                      Hodgson, William Hope
# 135                              Hardy, Thomas
# 138              Shiel, M. P. (Matthew Phipps)
# 142                        Falkner, John Meade
# 144                             Bramah, Ernest
# 146                              Eliot, George
# 147                                       None
# 158                           Sterne, Laurence
# 164                        Doyle, Arthur Conan
# ...                                        ...
# 5973            Orczy, Emmuska Orczy, Baroness
# 6038                            Dane, Clemence
# 6132                   Scott, Charles Augustus
# 6156                             Eliot, George
# 6219                               Thorne, Guy
# 6236                                Hays, Mary
# 6243                             Dunsany, Lord
# 6270                             Hope, Anthony
# 6387                          Smith, Alexander
# 6393                             Scott, Walter
# 6398                              Stoker, Bram
# 6412      Blackmore, R. D. (Richard Doddridge)
# 6434                              Austen, Jane
# 6616                           Castle, Egerton
# 6649          Shorthouse, J. H. (Joseph Henry)
# 6650          Shorthouse, J. H. (Joseph Henry)
# 6671                           Taylor, Meadows
# 6689      Blackmore, R. D. (Richard Doddridge)
# 6694                  Stacpoole, William Henry
# 6758                              Stoker, Bram
# 6790      Blackmore, R. D. (Richard Doddridge)
# 6847      Blackmore, R. D. (Richard Doddridge)
# 6848      Blackmore, R. D. (Richard Doddridge)
# 6849      Blackmore, R. D. (Richard Doddridge)
# 6895      Blackmore, R. D. (Richard Doddridge)
# 6909               Ainsworth, William Harrison
# 6944             Davies, W. H. (William Henry)
# 6945  James, G. P. R. (George Payne Rainsford)
# 6958             Wells, H. G. (Herbert George)
# 6959                                      None
#
#                                               wikipedia releaseDate  \
# 1     ['https://fr.wikipedia.org/wiki/La_Maison_au_b...        None
# 2     ['https://fr.wikipedia.org/wiki/Carmilla', 'ht...        None
# 16    ['https://en.wikipedia.org/wiki/The_Twilight_o...        None
# 24    ['https://fi.wikipedia.org/wiki/Ensimm%C3%A4is...        None
# 27                                                 None        None
# 28                                                 None        None
# 29                                                 None        None
# 30    ['https://en.wikipedia.org/wiki/Across_the_Zod...        None
# 31    ['https://fi.wikipedia.org/wiki/Poems_by_Curre...        None
# 34    ['https://ru.wikipedia.org/wiki/%D0%9F%D0%BE%D...        None
# 36    ['https://fr.wikipedia.org/wiki/Le_Professeur_...        None
# 40    ['https://en.wikipedia.org/wiki/Lady_into_Fox'...        None
# 57                                                 None        None
# 66    ['https://fa.wikipedia.org/wiki/%D9%88%D9%86%D...        None
# 73    ['https://en.wikipedia.org/wiki/The_New_Machia...        None
# 77    ['https://fi.wikipedia.org/wiki/Viisasteleva_s...        None
# 80    ['https://ru.wikipedia.org/wiki/Sartor_Resartu...        None
# 87    ['https://ar.wikipedia.org/wiki/%D9%82%D9%88%D...        None
# 92                                                 None  1934-10-05
# 93                                                 None        None
# 114   ['https://uk.wikipedia.org/wiki/%D0%A1%D0%B2%D...        None
# 130   ['https://ar.wikipedia.org/wiki/%D8%A3%D8%B1%D...        None
# 135   ['https://fr.wikipedia.org/wiki/Loin_de_la_fou...        None
# 138                                                None        None
# 142   ['https://ar.wikipedia.org/wiki/%D9%85%D9%88%D...        None
# 144   ['https://en.wikipedia.org/wiki/The_Wallet_of_...        None
# 146                                                None        None
# 147                                                None        None
# 158   ['https://fi.wikipedia.org/wiki/Tristram_Shand...        None
# 164   ['https://fa.wikipedia.org/wiki/%D8%A8%D8%A7%D...        None
# ...                                                 ...         ...
# 5973                                               None        None
# 6038                                               None        None
# 6132                                               None        None
# 6156                                               None        None
# 6219                                               None  2014-11-07
# 6236                                               None        None
# 6243                                               None        None
# 6270                                               None        None
# 6387                                               None        None
# 6393                                               None        None
# 6398                                               None        None
# 6412                                               None        None
# 6434                                               None  1813-01-28
# 6616                                               None        None
# 6649                                               None        None
# 6650                                               None        None
# 6671                                               None        None
# 6689                                               None        None
# 6694                                               None        None
# 6758                                               None        None
# 6790                                               None        None
# 6847                                               None        None
# 6848                                               None        None
# 6849                                               None        None
# 6895                                               None        None
# 6909                                               None        None
# 6944                                               None        None
# 6945                                               None        None
# 6958                                               None        None
# 6959                                               None        None
#
#                                            wikiSubjects  \
# 1     ['Novels_by_William_Hope_Hodgson', 'Science_fi...
# 2     ['1872_novels', 'Lesbian_novels', 'Fictional_v...
# 16    ['Fantasy_short_story_collections', '1888_shor...
# 24    ['Moon_in_fiction', 'British_novels_adapted_in...
# 27    ["American_children's_novels", 'Novels_by_Howa...
# 28    ['Dracula_in_written_fiction', 'Books_publishe...
# 29    ['Dracula_in_written_fiction', 'Books_publishe...
# 30    ['Mars_in_fiction', 'Novels_set_in_the_1830s',...
# 31    ['1846_books', 'Brontë_poems', 'English_poetry...
# 34    ['Scottish_novels', 'Midway_Atoll', '1892_nove...
# 36    ['Novels_set_in_schools', '19th-century_Britis...
# 40    ['Bloomsbury_Group_publications', 'Shapeshifti...
# 57    ['Sonnets', 'Early_Modern_English_poems', 'Son...
# 66    ['Works_based_on_Metamorphoses', 'Poetry_by_Wi...
# 73    ['Works_originally_published_in_The_English_Re...
# 77    ['Novels_about_nobility', 'John_Murray_(publis...
# 80    ['Existentialist_novels', 'Works_by_Thomas_Car...
# 87    ['Chapman_&_Hall_books', '1907_novels', 'Lost_...
# 92    ['British_novels', 'British_comedy_novels', 'H...
# 93    ['Hodder_&_Stoughton_books', 'Fictional_detect...
# 114   ['Novels_by_H._G._Wells', 'World_War_I_novels'...
# 130   ['Novels_by_William_Hope_Hodgson', '1912_novel...
# 135   ['British_novels_adapted_into_films', '19th-ce...
# 138   ['Single-writer_horror_short_story_collections...
# 142   ['1898_novels', 'Novels_set_in_the_18th_centur...
# 144   ['1900_short_story_collections', 'Single-write...
# 146   ['1879_books', 'Works_by_George_Eliot', 'Novel...
# 147   ['1879_books', 'Works_by_George_Eliot', 'Novel...
# 158   ['18th-century_British_novels', 'Picaresque_no...
# 164   ['Collections_of_Sherlock_Holmes_stories_by_Ar...
# ...                                                 ...
# 5973  ['Jacobites', 'English_Jacobites', 'Historical...
# 6038  ['British_LGBT_novels', 'British_novels', 'Les...
# 6132  ['Fictional_knights', '19th-century_novels', '...
# 6156  ['Novels_about_politicians', 'Novels_set_in_th...
# 6219  ['2014_books', 'Cosmology_books', 'Popular_sci...
# 6236  ['Adultery_in_novels', 'English_philosophical_...
# 6243  ['1914_books', 'Plays_by_Edward_Plunkett,_18th...
# 6270  ['English_adventure_novels', '1896_novels', 'N...
# 6387      ['1971_books', 'American_poetry_collections']
# 6393  ['Shetland', 'Pirate_books', 'Historical_novel...
# 6398  ['Doubleday,_Page_&_Company_books', 'Novels_by...
# 6412  ['1897_novels', 'Novels_by_Richard_Doddridge_B...
# 6434  ['19th-century_novels', 'Love_stories', 'Novel...
# 6616  ['Castle_(franchise)', '2013_novels', 'Detecti...
# 6649  ['1881_novels', 'Novels_set_in_the_17th_centur...
# 6650  ['1881_novels', 'Novels_set_in_the_17th_centur...
# 6671  ['Novels_set_in_India', 'Novels_set_in_the_183...
# 6689  ['Novels_by_Richard_Doddridge_Blackmore', 'Nov...
# 6694  ['Novels_set_on_islands', 'Novels_by_Henry_De_...
# 6758  ['North_Yorkshire', 'Invasion_literature', 'Va...
# 6790  ['Novels_set_in_Devon', 'Novels_set_in_Wales',...
# 6847  ['Novels_by_Richard_Doddridge_Blackmore', 'New...
# 6848  ['Novels_by_Richard_Doddridge_Blackmore', 'New...
# 6849  ['Novels_by_Richard_Doddridge_Blackmore', 'New...
# 6895  ['Novels_by_Richard_Doddridge_Blackmore', '189...
# 6909  ['Works_originally_published_in_American_magaz...
# 6944  ['1908_books', 'British_autobiographical_novel...
# 6945  ['Climate_change_books', '2006_books', 'Enviro...
# 6958  ['Moon_in_fiction', 'British_novels_adapted_in...
# 6959  ['Moon_in_fiction', 'British_novels_adapted_in...
#
#                                        literaryGenres  \
# 1                                  ['Horror_fiction']
# 2                                  ['Gothic_fiction']
# 16                                        ['Fantasy']
# 24                                                NaN
# 27    ['Historical_fiction', "Children's_literature"]
# 28                                                NaN
# 29                                                NaN
# 30                 ['List_of_science_fiction_novels']
# 31                                                NaN
# 34                              ['Adventure_fiction']
# 36                                                NaN
# 40                             ['Fantasy_literature']
# 57                         ['Renaissance_literature']
# 66                                                NaN
# 73                                                NaN
# 77                                                NaN
# 80                     ['Sui_generis', 'Comic_novel']
# 87                                 ['Horror_fiction']
# 92                                                NaN
# 93                                                NaN
# 114                                               NaN
# 130                            ['Fantasy_literature']
# 135                                               NaN
# 138     ['Detective_fiction', 'Supernatural_fiction']
# 142                             ['Adventure_fiction']
# 144                                       ['Fantasy']
# 146                                               NaN
# 147                                               NaN
# 158                                               NaN
# 164                             ['Detective_fiction']
# ...                                               ...
# 5973                                              NaN
# 6038                                              NaN
# 6132      ['Chivalric_romance', 'Historical_fiction']
# 6156                                 ['Social_novel']
# 6219                                              NaN
# 6236                                              NaN
# 6243                                      ['Fantasy']
# 6270                           ['Historical_fiction']
# 6387                                       ['Poetry']
# 6393                           ['Historical_fiction']
# 6398                                              NaN
# 6412                                              NaN
# 6434                             ['Novel_of_manners']
# 6616             ['Crime_fiction', 'Mystery_fiction']
# 6649                                              NaN
# 6650                                              NaN
# 6671                                        ['Novel']
# 6689                                              NaN
# 6694                                ['Romance_novel']
# 6758             ['Gothic_fiction', 'Horror_fiction']
# 6790                                              NaN
# 6847                                              NaN
# 6848                                              NaN
# 6849                                              NaN
# 6895                                              NaN
# 6909                                              NaN
# 6944                                              NaN
# 6945                                              NaN
# 6958                                              NaN
# 6959                                              NaN
#
#                                                    info
# 1     {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 2     {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 16    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 24    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 27    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 28    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 29    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 30    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 31    {'http://www.w3.org/2000/01/rdf-schema#label':...
# 34    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 36    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 40    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 57    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 66    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 73    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 77    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 80    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 87    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 92    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 93    {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 114   {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 130   {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 135   {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 138   {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 142   {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 144   {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 146   {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 147   {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 158   {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 164   {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# ...                                                 ...
# 5973  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6038  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6132  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6156  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6219  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6236  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6243  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6270  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6387  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6393  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6398  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6412  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6434  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6616  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6649  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6650  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6671  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6689  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6694  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6758  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6790  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6847  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6848  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6849  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6895  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6909  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6944  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6945  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6958  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 6959  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
#
# [741 rows x 8 columns]

# %%
df = df.rename(columns={"subjects": "wikiSubjects"})

# %%
df.to_sql('pg', conn, if_exists='append')
